# %% [markdown]
# # Logistic Regression Homework
#
# This is the 2nd assignment for CAP 4630 and we will implement logistic regression and apply it to two
# different datasets. \
# You will use **"Tasks"** and **"Hints"** to finish the work. **(Total 100 Points)** \
# You are **not** allowed to use Machine Learning libaries such as Scikit-learn and Keras.
#
# **Task Overview:**
# - Logistic Regression
# - Regularized Logistic Regression

# %% [markdown]
# ## 1 - Logistic Regression ##
# ### 1.1 Packages
#
# Import useful packages for scientific computing and data processing.
#
# **Tasks:**
# 1. Import numpy and rename it to np.
# 2. Import pandas and rename it to pd.
# 3. Import the pyplot function in the libraray of matplotlib and rename it to plt.
#
# References:
# - [numpy](www.numpy.org) is the fundamental package for scientific computing with Python.
# - [matplotlib](http://matplotlib.org) is a famous library to plot graphs in Python.
#
# **Attention:**
# 1. After this renaming, you will use the new name to call functions. For example, **numpy** will become **np** in the following sections.

# %%
### Import and rename libraries here
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### 1.2 - Data Preparation ##
#
# Prepare the data for regression task. **(15 Points)**
#
# **Tasks:**
# 1. Load data for logistic regression.
# 2. **Generate the SCATTER PLOT of the data**.
#
# **Hints:**
# 1. The data file is "data_logistic.csv", which are exam scores for students.
# 2. The data is organized by column: x1 (exam 1 score), x2 (exam 2 score), and label y (pass 1 or fail 0).
# 3. Please use different colors for postive(label=1) and negative(label=0) data.
# 4. An example of scatter plots is shown below.
# ![image.png](data:image/png;base64,...)

# %%
### Preprocess input data and generate plots
data = pd.read_csv('data_logistic.csv')
x = data.iloc[:, [0,1]]
y = data.iloc[:, 2]

def plotData(X, Y):
    pos_y = []
    neg_y = []
    for idx, val in enumerate(Y):
        if val == 1:
            pos_y.append(idx)
        else:
            neg_y.append(idx)
    if(type(X) is pd.DataFrame):
        X = pd.DataFrame(X).to_numpy()
    posX1 = X[np.array(pos_y), np.array([0])]
    posX2 = X[np.array(pos_y), np.array([1])]
    negX1 = X[np.array(neg_y), np.array([0])]
    negX2 = X[np.array(neg_y), np.array([1])]
      
    plt.scatter(posX1, posX2, c="#2bff00", marker="+", label="Positive")
    plt.scatter(negX1, negX2, c="#ff0000", marker="o", label="Negative")
    plt.legend()
    plt.xlabel('x1')
    plt.ylabel('x2')

plotData(x, y)
plt.show()

# %% [markdown]
# ### 1.3 - Sigmoid function ##
#
#
# Implement sigmoid function so it can be called by the rest of your program. **(15 Points)**
#
# **Tasks:**
# 1. Implement the sigmoid function (**def sigmoid(z):**).
# 2. Test the sigmoid function by function **plotting** with test data (X, Y) where Y = sigmoid(X).
#
# **Hints:**
# 1. Given the class material, sigmoid function is defined as:
# $g(z) = \frac{1}{1+e^{-z}}$.
# 2. You may consider X = np.linspace(-5, 5, 1000) to plot the curve.
# 3. Plot Y against X.
# 4. An example of plot for validation is shown below:
# ![image.png](data:image/png;base64,...)

# %%
### Implement sigmoid fuction here

# def sigmoid(z):
def sigmoid(z):
    return 1/(1+np.exp(-z))

# %%
### Plot data here

X = np.linspace(-5, 5, 1000)
plt.plot(X, sigmoid(X), 'b-')
plt.xlabel('x')
plt.ylabel('g(x)')
plt.show()

# %% [markdown]
# ### 1.4 - Cost function and gradient ##
#
# Implement the cross entropy cost function and its gradient for logistic regression. **(30 Points)**
#
# **Tasks:**
# 1. Implement the "cal_cost" to compute the cost.
# 2. Implement the "cal_grad" to compute the gradients.
# 3. Test "cal_cost" and "cal_grad" with initial values and print out the results.
#
# **Hint:**
# 1. The cross entropy cost function (J(θ)) in logistic regression is shown below. It involves two terms, including ylog(h) and (1-y)log(1-h) where h is the function of x.
# ![image.png](data:image/png;base64,...)
# 2. The gradient of the cost J(θ) is a vector of the same length as θ where the $j$th element (for $j = 0, 1, . . . , n)$ is defined below. You may do a hand calculation to justify the first order derivative with the term above.
# ![image.png](data:image/png;base64,...)
# 3. When you implement J(θ), please use eps = 1e-15 to prevent possible "divide by 0 exception" in second term. You may think about the reason.
# 4. You may consider the below templates for two functions:
#
#     def cal_cost(theta, X, y):
#
#         htheta = ...
#         term1 = ...  /* matrix_multiplication(log(htheta), y)
#         term2 = ...  /* matrix_multiplication(log(1-htheta+eps), (1-y))
#         J = - 1 / m * (term1 + term2)
#
#         return cost
#
#
#     def cal_grad(theta, X, y):
#
#         htheta = ...
#         term1 = ... /* matrix_multiplication(transpose(X), (htheta - y))  //you may think about why transpose(x)
#         grad = 1 / m * term1
#
#         return grad
# 5. It involves matrix multiplication and you may consider the function of np.matmul or np.dot.
#
# 6. Initialize the intercept term (constant term) with **ones** and the theta with **zeros**. Test the functions with these initial values. \
#     **Expected outputs:**\
#     Cost at initial theta : 0.6931471805599445\
#     Gradient at inital theta : [-0.1        -10.91242026 -11.73652937]

# %%
# Implement the cost function here

def cal_cost(theta, X, Y):
    m = X.shape[0]
    eps = 1e-15
    htheta = sigmoid(np.dot(X, theta))
    
    J = -(1/m) * np.sum(Y * np.log(htheta) + (1 - Y) * np.log(1 - htheta))
    
    return J

############################################
def cal_grad(theta, X, Y):

    # compute the hypothesis
    m = X.shape[0]
    htheta = sigmoid(np.dot(X, theta))
    
    return (1 / m) * np.dot(X.T, htheta - Y)


###  m, n = shape(feature data x), and thus, m = number of data and n = 2
m, n = np.shape(x)
x = np.hstack((np.ones((m, 1)), x))
#initialize theta
initial_theta = np.zeros(n + 1)

# # compute and display initial cost and gradient
J = cal_cost(initial_theta, x, y) # y is label (see the data loading block)
grad = cal_grad(initial_theta, x, y)
    
print ('Cost at initial theta: {0}\n'.format(J))
print ('Gradient at inital theta: {0}\n'.format(grad))
# Out:
# Cost at initial theta: 0.6931471805599454
#
# Gradient at inital theta: [ -0.1        -10.91242026 -11.73652937]

# %% [markdown]
# ## 1.5 Train parameters with Gradient Descent ##
#
#
# Train parameters using Gradient Descent. **(10 Points)**
#
# **Tasks:**
# 1. Calculate best fit theta by Gradient Descent with learning rate of **0.001 (1e-3)** and epoch of **80K**. The initial theta from above blocks is used as initial values.
# 2. Print out the best theta (the last one is considered as the best here) and its corresponding cost.
# 3. **Plot the decision boundary**.
#
# **Hints:**
# 1. You may take gradient descent in homework 1 as an template.
# 2. Derive the boundary line from **sigmoid(theta[0]+ X1 * theta[1] + X2* theta[2])=0.5**. Think about why we get the line by setting **the activated probability to 0.5**. Also, try to calculate the final relationship between X1 and X2. When sigmoid(X) = 0.5, what is the value of x? Check the generated plot in 1.3.
# 3. The validation of first 5 epochs (updated theta and cost): \
# ------Epoch 0------\
# Theta: [0.0001     0.01091242 0.01173653]\
# Cost: 0.6996118077359638\
# ------Epoch 1------\
# Theta: [-0.0001129   0.00053949  0.00229352]\
# Cost: 0.6649331468590681\
# ------Epoch 2------\
# Theta: [-5.93604956e-05  8.33145873e-03  1.07754324e-02]\
# Cost: 0.6679914364992459\
# ------Epoch 3------\
# Theta: [-0.0002356   0.0004607   0.00370829]\
# Cost: 0.6545873034874964\
# ------Epoch 4------\
# Theta: [-0.00020363  0.00683227  0.01065138]\
# Cost: 0.6563302142684528
# 4. You may take the plots below as an exmample:
#
# ![image.png](data:image/png;base64,...)
# 5. It may take ~1 min to finish running.

# %%
# Gradient Descent Implementation Here

theta = initial_theta
lr = 1e-3

for epoch in range(80000):
    J = cal_cost(theta, x, y)
    grad = cal_grad(theta, x, y)
    theta = theta - np.dot(lr, grad) # parameter update rule of gradient descent
    print('-----Epoch {0}-----'.format(epoch))
    print ('Theta: {0}'.format(theta))
    print ('Cost: {0}'.format(cal_cost(theta, x, y)))
# Out:
# 48114986
# -----Epoch 79459-----
# Theta: [-3.86383442  0.02932759  0.0392097 ]
# Cost: 0.439090551123875
# -----Epoch 79460-----
# Theta: [-3.86387052  0.02932787  0.03920997]
# Cost: 0.4390892474526582
# -----Epoch 79461-----
# Theta: [-3.86390663  0.02932816  0.03921023]
# Cost: 0.4390879437978479
# -----Epoch 79462-----
# Theta: [-3.86394273  0.02932844  0.0392105 ]
# Cost: 0.4390866401594437
# -----Epoch 79463-----
# Theta: [-3.86397883  0.02932872  0.03921077]
# Cost: 0.43908533653744564
# -----Epoch 79464-----
# Theta: [-3.86401494  0.029329    0.03921104]
# Cost: 0.4390840329318529
# -----Epoch 79465-----
# Theta: [-3.86405104  0.02932929  0.03921131]
# Cost: 0.43908272934266573
# -----Epoch 79466-----
# Theta: [-3.86408714  0.02932957  0.03921158]
# Cost: 0.4390814257698834
# -----Epoch 79467-----
# Theta: [-3.86412325  0.02932985  0.03921185]
# Cost: 0.43908012221350606
# -----Epoch 79468-----
# Theta: [-3.86415935  0.02933013  0.03921211]
# Cost: 0.43907881867353293
# -----Epoch 79469-----
# Theta: [-3.86419545  0.02933042  0.03921238]
# Cost: 0.4390775151499641
# -----Epoch 79470-----
# Theta: [-3.86423155  0.0293307   0.03921265]
# Cost: 0.43907621164279925
# -----Epoch 79471-----
# Theta: [-3.86426766  0.02933098  0.03921292]
# Cost: 0.439074908152038
# -----Epoch 79472-----
# Theta: [-3.86430376  0.02933126  0.03921319]
# Cost: 0.43907360467768
# -----Epoch 79473-----
# Theta: [-3.86433986  0.02933155  0.03921346]
# Cost: 0.439072301219725
# -----Epoch 79474-----
# Theta: [-3.86437596  0.02933183  0.03921373]
# Cost: 0.4390709977781728
# -----Epoch 79475-----
# Theta: [-3.86441206  0.02933211  0.03921399]
# Cost: 0.439069694353023
# -----Epoch 79476-----
# Theta: [-3.86444816  0.02933239  0.03921426]
# Cost: 0.4390683909442754
# -----Epoch 79477-----
# Theta: [-3.86448426  0.02933267  0.03921453]
# Cost: 0.4390670875519298
# -----Epoch 79478-----
# Theta: [-3.86452036  0.02933296  0.0392148 ]
# Cost: 0.4390657841759857
# -----Epoch 79479-----
# Theta: [-3.86455646  0.02933324  0.03921507]
# Cost: 0.4390644808164428
# -----Epoch 79480-----
# Theta: [-3.86459256  0.02933352  0.03921534]
# Cost: 0.43906317747330104
# -----Epoch 79481-----
# Theta: [-3.86462866  0.0293338   0.03921561]
# Cost: 0.43906187414656
# -----Epoch 79482-----
# Theta: [-3.86466476  0.02933409  0.03921587]
# Cost: 0.43906057083621947
# -----Epoch 79483-----
# Theta: [-3.86470086  0.02933437  0.03921614]
# Cost: 0.439059267542279
# -----Epoch 79484-----
# Theta: [-3.86473696  0.02933465  0.03921641]
# Cost: 0.4390579642647384
# -----Epoch 79485-----
# Theta: [-3.86477306  0.02933493  0.03921668]
# Cost: 0.43905666100359736
# -----Epoch 79486-----
# Theta: [-3.86480916  0.02933522  0.03921695]
# Cost: 0.43905535775885574
# -----Epoch 79487-----
# Theta: [-3.86484525  0.0293355   0.03921722]
# Cost: 0.43905405453051305
# -----Epoch 79488-----
# Theta: [-3.86488135  0.02933578  0.03921748]
# Cost: 0.43905275131856913
# -----Epoch 79489-----
# Theta: [-3.86491745  0.02933606  0.03921775]
# Cost: 0.4390514481230236
# -----Epoch 79490-----
# Theta: [-3.86495355  0.02933635  0.03921802]
# Cost: 0.43905014494387623
# -----Epoch 79491-----
# Theta: [-3.86498964  0.02933663  0.03921829]
# Cost: 0.43904884178112663
# -----Epoch 79492-----
# Theta: [-3.86502574  0.02933691  0.03921856]
# Cost: 0.43904753863477475
# -----Epoch 79493-----
# Theta: [-3.86506184  0.02933719  0.03921883]
# Cost: 0.43904623550482
# -----Epoch 79494-----
# Theta: [-3.86509794  0.02933748  0.0392191 ]
# Cost: 0.43904493239126235
# -----Epoch 79495-----
# Theta: [-3.86513403  0.02933776  0.03921936]
# Cost: 0.43904362929410135
# -----Epoch 79496-----
# Theta: [-3.86517013  0.02933804  0.03921963]
# Cost: 0.4390423262133369
# -----Epoch 79497-----
# Theta: [-3.86520622  0.02933832  0.0392199 ]
# Cost: 0.4390410231489685
# -----Epoch 79498-----
# Theta: [-3.86524232  0.02933861  0.03922017]
# Cost: 0.43903972010099584
# -----Epoch 79499-----
# Theta: [-3.86527842  0.02933889  0.03922044]
# Cost: 0.4390384170694189
# -----Epoch 79500-----
# Theta: [-3.86531451  0.02933917  0.03922071]
# Cost: 0.43903711405423707
# -----Epoch 79501-----
# Theta: [-3.86535061  0.02933945  0.03922098]
# Cost: 0.43903581105545036
# -----Epoch 79502-----
# Theta: [-3.8653867   0.02933973  0.03922124]
# Cost: 0.4390345080730583
# -----Epoch 79503-----
# Theta: [-3.86542279  0.02934002  0.03922151]
# Cost: 0.4390332051070607
# -----Epoch 79504-----
# Theta: [-3.86545889  0.0293403   0.03922178]
# Cost: 0.43903190215745724
# -----Epoch 79505-----
# Theta: [-3.86549498  0.02934058  0.03922205]
# Cost: 0.4390305992242475
# -----Epoch 79506-----
# Theta: [-3.86553108  0.02934086  0.03922232]
# Cost: 0.43902929630743137
# -----Epoch 79507-----
# Theta: [-3.86556717  0.02934115  0.03922259]
# Cost: 0.4390279934070085
# -----Epoch 79508-----
# Theta: [-3.86560326  0.02934143  0.03922285]
# Cost: 0.4390266905229786
# -----Epoch 79509-----
# Theta: [-3.86563936  0.02934171  0.03922312]
# Cost: 0.43902538765534144
# -----Epoch 79510-----
# Theta: [-3.86567545  0.02934199  0.03922339]
# Cost: 0.4390240848040966
# -----Epoch 79511-----
# Theta: [-3.86571154  0.02934228  0.03922366]
# Cost: 0.4390227819692439
# -----Epoch 79512-----
# Theta: [-3.86574764  0.02934256  0.03922393]
# Cost: 0.43902147915078304
# -----Epoch 79513-----
# Theta: [-3.86578373  0.02934284  0.0392242 ]
# Cost: 0.4390201763487137
# -----Epoch 79514-----
# Theta: [-3.86581982  0.02934312  0.03922447]
# Cost: 0.4390188735630356
# -----Epoch 79515-----
# Theta: [-3.86585591  0.02934341  0.03922473]
# Cost: 0.4390175707937485
# -----Epoch 79516-----
# Theta: [-3.865892    0.02934369  0.039225  ]
# Cost: 0.43901626804085203
# -----Epoch 79517-----
# Theta: [-3.86592809  0.02934397  0.03922527]
# Cost: 0.43901496530434597
# -----Epoch 79518-----
# Theta: [-3.86596419  0.02934425  0.03922554]
# Cost: 0.4390136625842301
# -----Epoch 79519-----
# Theta: [-3.86600028  0.02934453  0.03922581]
# Cost: 0.43901235988050386
# -----Epoch 79520-----
# Theta: [-3.86603637  0.02934482  0.03922608]
# Cost: 0.4390110571931673
# -----Epoch 79521-----
# Theta: [-3.86607246  0.0293451   0.03922634]
# Cost: 0.4390097545222199
# -----Epoch 79522-----
# Theta: [-3.86610855  0.02934538  0.03922661]
# Cost: 0.43900845186766146
# -----Epoch 79523-----
# Theta: [-3.86614464  0.02934566  0.03922688]
# Cost: 0.4390071492294917
# -----Epoch 79524-----
# Theta: [-3.86618073  0.02934595  0.03922715]
# Cost: 0.43900584660771025
# -----Epoch 79525-----
# Theta: [-3.86621682  0.02934623  0.03922742]
# Cost: 0.4390045440023171
# -----Epoch 79526-----
# Theta: [-3.86625291  0.02934651  0.03922769]
# Cost: 0.43900324141331154
# -----Epoch 79527-----
# Theta: [-3.866289    0.02934679  0.03922796]
# Cost: 0.4390019388406936
# -----Epoch 79528-----
# Theta: [-3.86632509  0.02934708  0.03922822]
# Cost: 0.43900063628446273
# -----Epoch 79529-----
# Theta: [-3.86636117  0.02934736  0.03922849]
# Cost: 0.43899933374461897
# -----Epoch 79530-----
# Theta: [-3.86639726  0.02934764  0.03922876]
# Cost: 0.4389980312211618
# -----Epoch 79531-----
# Theta: [-3.86643335  0.02934792  0.03922903]
# Cost: 0.43899672871409107
# -----Epoch 79532-----
# Theta: [-3.86646944  0.02934821  0.0392293 ]
# Cost: 0.43899542622340637
# -----Epoch 79533-----
# Theta: [-3.86650553  0.02934849  0.03922957]
# Cost: 0.43899412374910746
# -----Epoch 79534-----
# Theta: [-3.86654161  0.02934877  0.03922983]
# Cost: 0.438992821291194
# -----Epoch 79535-----
# Theta: [-3.8665777   0.02934905  0.0392301 ]
# Cost: 0.43899151884966586
# -----Epoch 79536-----
# Theta: [-3.86661379  0.02934933  0.03923037]
# Cost: 0.4389902164245227
# -----Epoch 79537-----
# Theta: [-3.86664988  0.02934962  0.03923064]
# Cost: 0.43898891401576406
# -----Epoch 79538-----
# Theta: [-3.86668596  0.0293499   0.03923091]
# Cost: 0.43898761162338973
# -----Epoch 79539-----
# Theta: [-3.86672205  0.02935018  0.03923118]
# Cost: 0.4389863092473997
# -----Epoch 79540-----
# Theta: [-3.86675813  0.02935046  0.03923144]
# Cost: 0.4389850068877932
# -----Epoch 79541-----
# Theta: [-3.86679422  0.02935075  0.03923171]
# Cost: 0.4389837045445704
# -----Epoch 79542-----
# Theta: [-3.86683031  0.02935103  0.03923198]
# Cost: 0.4389824022177307
# -----Epoch 79543-----
# Theta: [-3.86686639  0.02935131  0.03923225]
# Cost: 0.4389810999072739
# -----Epoch 79544-----
# Theta: [-3.86690248  0.02935159  0.03923252]
# Cost: 0.43897979761319983
# -----Epoch 79545-----
# Theta: [-3.86693856  0.02935188  0.03923279]
# Cost: 0.4389784953355081
# -----Epoch 79546-----
# Theta: [-3.86697465  0.02935216  0.03923306]
# Cost: 0.43897719307419836
# -----Epoch 79547-----
# Theta: [-3.86701073  0.02935244  0.03923332]
# Cost: 0.4389758908292704
# -----Epoch 79548-----
# Theta: [-3.86704682  0.02935272  0.03923359]
# Cost: 0.4389745886007239
# -----Epoch 79549-----
# Theta: [-3.8670829   0.029353    0.03923386]
# Cost: 0.4389732863885586
# -----Epoch 79550-----
# Theta: [-3.86711898  0.02935329  0.03923413]
# Cost: 0.43897198419277433
# -----Epoch 79551-----
# Theta: [-3.86715507  0.02935357  0.0392344 ]
# Cost: 0.43897068201337053
# -----Epoch 79552-----
# Theta: [-3.86719115  0.02935385  0.03923467]
# Cost: 0.4389693798503473
# -----Epoch 79553-----
# Theta: [-3.86722723  0.02935413  0.03923493]
# Cost: 0.43896807770370394
# -----Epoch 79554-----
# Theta: [-3.86726332  0.02935442  0.0392352 ]
# Cost: 0.43896677557344044
# -----Epoch 79555-----
# Theta: [-3.8672994   0.0293547   0.03923547]
# Cost: 0.43896547345955633
# -----Epoch 79556-----
# Theta: [-3.86733548  0.02935498  0.03923574]
# Cost: 0.43896417136205135
# -----Epoch 79557-----
# Theta: [-3.86737156  0.02935526  0.03923601]
# Cost: 0.43896286928092537
# -----Epoch 79558-----
# Theta: [-3.86740765  0.02935555  0.03923628]
# Cost: 0.4389615672161781
# -----Epoch 79559-----
# Theta: [-3.86744373  0.02935583  0.03923654]
# Cost: 0.43896026516780895
# -----Epoch 79560-----
# Theta: [-3.86747981  0.02935611  0.03923681]
# Cost: 0.43895896313581795
# -----Epoch 79561-----
# Theta: [-3.86751589  0.02935639  0.03923708]
# Cost: 0.43895766112020473
# -----Epoch 79562-----
# Theta: [-3.86755197  0.02935667  0.03923735]
# Cost: 0.43895635912096903
# -----Epoch 79563-----
# Theta: [-3.86758805  0.02935696  0.03923762]
# Cost: 0.43895505713811034
# -----Epoch 79564-----
# Theta: [-3.86762413  0.02935724  0.03923789]
# Cost: 0.43895375517162877
# -----Epoch 79565-----
# Theta: [-3.86766021  0.02935752  0.03923815]
# Cost: 0.43895245322152365
# -----Epoch 79566-----
# Theta: [-3.8676963   0.0293578   0.03923842]
# Cost: 0.4389511512877948
# -----Epoch 79567-----
# Theta: [-3.86773238  0.02935809  0.03923869]
# Cost: 0.4389498493704421
# -----Epoch 79568-----
# Theta: [-3.86776846  0.02935837  0.03923896]
# Cost: 0.43894854746946504
# -----Epoch 79569-----
# Theta: [-3.86780453  0.02935865  0.03923923]
# Cost: 0.4389472455848637
# -----Epoch 79570-----
# Theta: [-3.86784061  0.02935893  0.0392395 ]
# Cost: 0.4389459437166373
# -----Epoch 79571-----
# Theta: [-3.86787669  0.02935921  0.03923976]
# Cost: 0.43894464186478577
# -----Epoch 79572-----
# Theta: [-3.86791277  0.0293595   0.03924003]
# Cost: 0.438943340029309
# -----Epoch 79573-----
# Theta: [-3.86794885  0.02935978  0.0392403 ]
# Cost: 0.43894203821020633
# -----Epoch 79574-----
# Theta: [-3.86798493  0.02936006  0.03924057]
# Cost: 0.4389407364074779
# -----Epoch 79575-----
# Theta: [-3.86802101  0.02936034  0.03924084]
# Cost: 0.43893943462112306
# -----Epoch 79576-----
# Theta: [-3.86805709  0.02936063  0.03924111]
# Cost: 0.43893813285114175
# -----Epoch 79577-----
# Theta: [-3.86809316  0.02936091  0.03924137]
# Cost: 0.43893683109753356
# -----Epoch 79578-----
# Theta: [-3.86812924  0.02936119  0.03924164]
# Cost: 0.43893552936029834
# -----Epoch 79579-----
# Theta: [-3.86816532  0.02936147  0.03924191]
# Cost: 0.43893422763943557
# -----Epoch 79580-----
# Theta: [-3.8682014   0.02936175  0.03924218]
# Cost: 0.43893292593494526
# -----Epoch 79581-----
# Theta: [-3.86823747  0.02936204  0.03924245]
# Cost: 0.43893162424682686
# -----Epoch 79582-----
# Theta: [-3.86827355  0.02936232  0.03924272]
# Cost: 0.43893032257508013
# -----Epoch 79583-----
# Theta: [-3.86830963  0.0293626   0.03924299]
# Cost: 0.438929020919705
# -----Epoch 79584-----
# Theta: [-3.8683457   0.02936288  0.03924325]
# Cost: 0.43892771928070096
# -----Epoch 79585-----
# Theta: [-3.86838178  0.02936317  0.03924352]
# Cost: 0.4389264176580677
# -----Epoch 79586-----
# Theta: [-3.86841785  0.02936345  0.03924379]
# Cost: 0.43892511605180523
# -----Epoch 79587-----
# Theta: [-3.86845393  0.02936373  0.03924406]
# Cost: 0.4389238144619129
# -----Epoch 79588-----
# Theta: [-3.86849     0.02936401  0.03924433]
# Cost: 0.4389225128883906
# -----Epoch 79589-----
# Theta: [-3.86852608  0.02936429  0.0392446 ]
# Cost: 0.43892121133123807
# -----Epoch 79590-----
# Theta: [-3.86856215  0.02936458  0.03924486]
# Cost: 0.4389199097904549
# -----Epoch 79591-----
# Theta: [-3.86859823  0.02936486  0.03924513]
# Cost: 0.438918608266041
# -----Epoch 79592-----
# Theta: [-3.8686343   0.02936514  0.0392454 ]
# Cost: 0.43891730675799584
# -----Epoch 79593-----
# Theta: [-3.86867038  0.02936542  0.03924567]
# Cost: 0.43891600526631935
# -----Epoch 79594-----
# Theta: [-3.86870645  0.02936571  0.03924594]
# Cost: 0.43891470379101105
# -----Epoch 79595-----
# Theta: [-3.86874252  0.02936599  0.03924621]
# Cost: 0.43891340233207077
# -----Epoch 79596-----
# Theta: [-3.8687786   0.02936627  0.03924647]
# Cost: 0.4389121008894983
# -----Epoch 79597-----
# Theta: [-3.86881467  0.02936655  0.03924674]
# Cost: 0.4389107994632932
# -----Epoch 79598-----
# Theta: [-3.86885074  0.02936683  0.03924701]
# Cost: 0.43890949805345514
# -----Epoch 79599-----
# Theta: [-3.86888682  0.02936712  0.03924728]
# Cost: 0.43890819665998415
# -----Epoch 79600-----
# Theta: [-3.86892289  0.0293674   0.03924755]
# Cost: 0.43890689528287957
# -----Epoch 79601-----
# Theta: [-3.86895896  0.02936768  0.03924782]
# Cost: 0.43890559392214135
# -----Epoch 79602-----
# Theta: [-3.86899503  0.02936796  0.03924808]
# Cost: 0.4389042925777691
# -----Epoch 79603-----
# Theta: [-3.86903111  0.02936825  0.03924835]
# Cost: 0.4389029912497626
# -----Epoch 79604-----
# Theta: [-3.86906718  0.02936853  0.03924862]
# Cost: 0.4389016899381215
# -----Epoch 79605-----
# Theta: [-3.86910325  0.02936881  0.03924889]
# Cost: 0.4389003886428454
# -----Epoch 79606-----
# Theta: [-3.86913932  0.02936909  0.03924916]
# Cost: 0.4388990873639343
# -----Epoch 79607-----
# Theta: [-3.86917539  0.02936937  0.03924942]
# Cost: 0.4388977861013877
# -----Epoch 79608-----
# Theta: [-3.86921146  0.02936966  0.03924969]
# Cost: 0.4388964848552053
# -----Epoch 79609-----
# Theta: [-3.86924753  0.02936994  0.03924996]
# Cost: 0.43889518362538715
# -----Epoch 79610-----
# Theta: [-3.8692836   0.02937022  0.03925023]
# Cost: 0.43889388241193256
# -----Epoch 79611-----
# Theta: [-3.86931967  0.0293705   0.0392505 ]
# Cost: 0.4388925812148413
# -----Epoch 79612-----
# Theta: [-3.86935574  0.02937079  0.03925077]
# Cost: 0.43889128003411326
# -----Epoch 79613-----
# Theta: [-3.86939181  0.02937107  0.03925103]
# Cost: 0.43888997886974795
# -----Epoch 79614-----
# Theta: [-3.86942788  0.02937135  0.0392513 ]
# Cost: 0.43888867772174533
# -----Epoch 79615-----
# Theta: [-3.86946395  0.02937163  0.03925157]
# Cost: 0.43888737659010496
# -----Epoch 79616-----
# Theta: [-3.86950002  0.02937191  0.03925184]
# Cost: 0.43888607547482644
# -----Epoch 79617-----
# Theta: [-3.86953609  0.0293722   0.03925211]
# Cost: 0.4388847743759097
# -----Epoch 79618-----
# Theta: [-3.86957216  0.02937248  0.03925238]
# Cost: 0.4388834732933544
# -----Epoch 79619-----
# Theta: [-3.86960823  0.02937276  0.03925264]
# Cost: 0.4388821722271603
# -----Epoch 79620-----
# Theta: [-3.86964429  0.02937304  0.03925291]
# Cost: 0.4388808711773269
# -----Epoch 79621-----
# Theta: [-3.86968036  0.02937333  0.03925318]
# Cost: 0.43887957014385415
# -----Epoch 79622-----
# Theta: [-3.86971643  0.02937361  0.03925345]
# Cost: 0.4388782691267416
# -----Epoch 79623-----
# Theta: [-3.8697525   0.02937389  0.03925372]
# Cost: 0.438876968125989
# -----Epoch 79624-----
# Theta: [-3.86978856  0.02937417  0.03925399]
# Cost: 0.43887566714159604
# -----Epoch 79625-----
# Theta: [-3.86982463  0.02937445  0.03925425]
# Cost: 0.4388743661735626
# -----Epoch 79626-----
# Theta: [-3.8698607   0.02937474  0.03925452]
# Cost: 0.43887306522188824
# -----Epoch 79627-----
# Theta: [-3.86989676  0.02937502  0.03925479]
# Cost: 0.4388717642865727
# -----Epoch 79628-----
# Theta: [-3.86993283  0.0293753   0.03925506]
# Cost: 0.4388704633676157
# -----Epoch 79629-----
# Theta: [-3.8699689   0.02937558  0.03925533]
# Cost: 0.43886916246501695
# -----Epoch 79630-----
# Theta: [-3.87000496  0.02937586  0.0392556 ]
# Cost: 0.4388678615787762
# -----Epoch 79631-----
# Theta: [-3.87004103  0.02937615  0.03925586]
# Cost: 0.4388665607088932
# -----Epoch 79632-----
# Theta: [-3.87007709  0.02937643  0.03925613]
# Cost: 0.4388652598553675
# -----Epoch 79633-----
# Theta: [-3.87011316  0.02937671  0.0392564 ]
# Cost: 0.43886395901819886
# -----Epoch 79634-----
# Theta: [-3.87014922  0.02937699  0.03925667]
# Cost: 0.43886265819738707
# -----Epoch 79635-----
# Theta: [-3.87018529  0.02937728  0.03925694]
# Cost: 0.4388613573929318
# -----Epoch 79636-----
# Theta: [-3.87022135  0.02937756  0.03925721]
# Cost: 0.43886005660483285
# -----Epoch 79637-----
# Theta: [-3.87025741  0.02937784  0.03925747]
# Cost: 0.43885875583308986
# -----Epoch 79638-----
# Theta: [-3.87029348  0.02937812  0.03925774]
# Cost: 0.4388574550777025
# -----Epoch 79639-----
# Theta: [-3.87032954  0.0293784   0.03925801]
# Cost: 0.4388561543386706
# -----Epoch 79640-----
# Theta: [-3.87036561  0.02937869  0.03925828]
# Cost: 0.4388548536159938
# -----Epoch 79641-----
# Theta: [-3.87040167  0.02937897  0.03925855]
# Cost: 0.4388535529096717
# -----Epoch 79642-----
# Theta: [-3.87043773  0.02937925  0.03925881]
# Cost: 0.43885225221970414
# -----Epoch 79643-----
# Theta: [-3.8704738   0.02937953  0.03925908]
# Cost: 0.438850951546091
# -----Epoch 79644-----
# Theta: [-3.87050986  0.02937981  0.03925935]
# Cost: 0.43884965088883165
# -----Epoch 79645-----
# Theta: [-3.87054592  0.0293801   0.03925962]
# Cost: 0.4388483502479261
# -----Epoch 79646-----
# Theta: [-3.87058198  0.02938038  0.03925989]
# Cost: 0.43884704962337384
# -----Epoch 79647-----
# Theta: [-3.87061804  0.02938066  0.03926016]
# Cost: 0.43884574901517476
# -----Epoch 79648-----
# Theta: [-3.87065411  0.02938094  0.03926042]
# Cost: 0.4388444484233285
# -----Epoch 79649-----
# Theta: [-3.87069017  0.02938123  0.03926069]
# Cost: 0.43884314784783457
# -----Epoch 79650-----
# Theta: [-3.87072623  0.02938151  0.03926096]
# Cost: 0.438841847288693
# -----Epoch 79651-----
# Theta: [-3.87076229  0.02938179  0.03926123]
# Cost: 0.4388405467459034
# -----Epoch 79652-----
# Theta: [-3.87079835  0.02938207  0.0392615 ]
# Cost: 0.4388392462194656
# -----Epoch 79653-----
# Theta: [-3.87083441  0.02938235  0.03926177]
# Cost: 0.43883794570937895
# -----Epoch 79654-----
# Theta: [-3.87087047  0.02938264  0.03926203]
# Cost: 0.4388366452156435
# -----Epoch 79655-----
# Theta: [-3.87090653  0.02938292  0.0392623 ]
# Cost: 0.43883534473825886
# -----Epoch 79656-----
# Theta: [-3.87094259  0.0293832   0.03926257]
# Cost: 0.4388340442772247
# -----Epoch 79657-----
# Theta: [-3.87097865  0.02938348  0.03926284]
# Cost: 0.43883274383254084
# -----Epoch 79658-----
# Theta: [-3.87101471  0.02938376  0.03926311]
# Cost: 0.43883144340420693
# -----Epoch 79659-----
# Theta: [-3.87105077  0.02938405  0.03926337]
# Cost: 0.4388301429922226
# -----Epoch 79660-----
# Theta: [-3.87108683  0.02938433  0.03926364]
# Cost: 0.4388288425965877
# -----Epoch 79661-----
# Theta: [-3.87112289  0.02938461  0.03926391]
# Cost: 0.43882754221730186
# -----Epoch 79662-----
# Theta: [-3.87115895  0.02938489  0.03926418]
# Cost: 0.4388262418543648
# -----Epoch 79663-----
# Theta: [-3.871195    0.02938518  0.03926445]
# Cost: 0.43882494150777634
# -----Epoch 79664-----
# Theta: [-3.87123106  0.02938546  0.03926472]
# Cost: 0.4388236411775361
# -----Epoch 79665-----
# Theta: [-3.87126712  0.02938574  0.03926498]
# Cost: 0.4388223408636438
# -----Epoch 79666-----
# Theta: [-3.87130318  0.02938602  0.03926525]
# Cost: 0.43882104056609905
# -----Epoch 79667-----
# Theta: [-3.87133923  0.0293863   0.03926552]
# Cost: 0.4388197402849017
# -----Epoch 79668-----
# Theta: [-3.87137529  0.02938659  0.03926579]
# Cost: 0.43881844002005155
# -----Epoch 79669-----
# Theta: [-3.87141135  0.02938687  0.03926606]
# Cost: 0.4388171397715482
# -----Epoch 79670-----
# Theta: [-3.87144741  0.02938715  0.03926633]
# Cost: 0.43881583953939124
# -----Epoch 79671-----
# Theta: [-3.87148346  0.02938743  0.03926659]
# Cost: 0.4388145393235805
# -----Epoch 79672-----
# Theta: [-3.87151952  0.02938771  0.03926686]
# Cost: 0.43881323912411596
# -----Epoch 79673-----
# Theta: [-3.87155557  0.029388    0.03926713]
# Cost: 0.43881193894099674
# -----Epoch 79674-----
# Theta: [-3.87159163  0.02938828  0.0392674 ]
# Cost: 0.438810638774223
# -----Epoch 79675-----
# Theta: [-3.87162769  0.02938856  0.03926767]
# Cost: 0.43880933862379445
# -----Epoch 79676-----
# Theta: [-3.87166374  0.02938884  0.03926793]
# Cost: 0.4388080384897106
# -----Epoch 79677-----
# Theta: [-3.8716998   0.02938912  0.0392682 ]
# Cost: 0.43880673837197115
# -----Epoch 79678-----
# Theta: [-3.87173585  0.02938941  0.03926847]
# Cost: 0.4388054382705761
# -----Epoch 79679-----
# Theta: [-3.87177191  0.02938969  0.03926874]
# Cost: 0.43880413818552494
# -----Epoch 79680-----
# Theta: [-3.87180796  0.02938997  0.03926901]
# Cost: 0.4388028381168175
# -----Epoch 79681-----
# Theta: [-3.87184401  0.02939025  0.03926928]
# Cost: 0.4388015380644532
# -----Epoch 79682-----
# Theta: [-3.87188007  0.02939053  0.03926954]
# Cost: 0.43880023802843215
# -----Epoch 79683-----
# Theta: [-3.87191612  0.02939082  0.03926981]
# Cost: 0.4387989380087538
# -----Epoch 79684-----
# Theta: [-3.87195218  0.0293911   0.03927008]
# Cost: 0.43879763800541804
# -----Epoch 79685-----
# Theta: [-3.87198823  0.02939138  0.03927035]
# Cost: 0.43879633801842455
# -----Epoch 79686-----
# Theta: [-3.87202428  0.02939166  0.03927062]
# Cost: 0.43879503804777276
# -----Epoch 79687-----
# Theta: [-3.87206033  0.02939195  0.03927088]
# Cost: 0.4387937380934629
# -----Epoch 79688-----
# Theta: [-3.87209639  0.02939223  0.03927115]
# Cost: 0.43879243815549424
# -----Epoch 79689-----
# Theta: [-3.87213244  0.02939251  0.03927142]
# Cost: 0.43879113823386656
# -----Epoch 79690-----
# Theta: [-3.87216849  0.02939279  0.03927169]
# Cost: 0.43878983832857976
# -----Epoch 79691-----
# Theta: [-3.87220454  0.02939307  0.03927196]
# Cost: 0.4387885384396336
# -----Epoch 79692-----
# Theta: [-3.87224059  0.02939336  0.03927223]
# Cost: 0.4387872385670275
# -----Epoch 79693-----
# Theta: [-3.87227665  0.02939364  0.03927249]
# Cost: 0.4387859387107613
# -----Epoch 79694-----
# Theta: [-3.8723127   0.02939392  0.03927276]
# Cost: 0.4387846388708349
# -----Epoch 79695-----
# Theta: [-3.87234875  0.0293942   0.03927303]
# Cost: 0.43878333904724776
# -----Epoch 79696-----
# Theta: [-3.8723848   0.02939448  0.0392733 ]
# Cost: 0.4387820392399997
# -----Epoch 79697-----
# Theta: [-3.87242085  0.02939477  0.03927357]
# Cost: 0.43878073944909035
# -----Epoch 79698-----
# Theta: [-3.8724569   0.02939505  0.03927383]
# Cost: 0.43877943967451966
# -----Epoch 79699-----
# Theta: [-3.87249295  0.02939533  0.0392741 ]
# Cost: 0.43877813991628706
# -----Epoch 79700-----
# Theta: [-3.872529    0.02939561  0.03927437]
# Cost: 0.4387768401743925
# -----Epoch 79701-----
# Theta: [-3.87256505  0.02939589  0.03927464]
# Cost: 0.4387755404488354
# -----Epoch 79702-----
# Theta: [-3.8726011   0.02939618  0.03927491]
# Cost: 0.43877424073961574
# -----Epoch 79703-----
# Theta: [-3.87263715  0.02939646  0.03927517]
# Cost: 0.43877294104673314
# -----Epoch 79704-----
# Theta: [-3.8726732   0.02939674  0.03927544]
# Cost: 0.4387716413701873
# -----Epoch 79705-----
# Theta: [-3.87270925  0.02939702  0.03927571]
# Cost: 0.438770341709978
# -----Epoch 79706-----
# Theta: [-3.87274529  0.0293973   0.03927598]
# Cost: 0.43876904206610484
# -----Epoch 79707-----
# Theta: [-3.87278134  0.02939759  0.03927625]
# Cost: 0.4387677424385677
# -----Epoch 79708-----
# Theta: [-3.87281739  0.02939787  0.03927652]
# Cost: 0.4387664428273661
# -----Epoch 79709-----
# Theta: [-3.87285344  0.02939815  0.03927678]
# Cost: 0.4387651432325
# -----Epoch 79710-----
# Theta: [-3.87288949  0.02939843  0.03927705]
# Cost: 0.4387638436539689
# -----Epoch 79711-----
# Theta: [-3.87292553  0.02939871  0.03927732]
# Cost: 0.43876254409177246
# -----Epoch 79712-----
# Theta: [-3.87296158  0.029399    0.03927759]
# Cost: 0.4387612445459106
# -----Epoch 79713-----
# Theta: [-3.87299763  0.02939928  0.03927786]
# Cost: 0.438759945016383
# -----Epoch 79714-----
# Theta: [-3.87303368  0.02939956  0.03927812]
# Cost: 0.4387586455031893
# -----Epoch 79715-----
# Theta: [-3.87306972  0.02939984  0.03927839]
# Cost: 0.43875734600632915
# -----Epoch 79716-----
# Theta: [-3.87310577  0.02940012  0.03927866]
# Cost: 0.4387560465258023
# -----Epoch 79717-----
# Theta: [-3.87314181  0.02940041  0.03927893]
# Cost: 0.4387547470616087
# -----Epoch 79718-----
# Theta: [-3.87317786  0.02940069  0.0392792 ]
# Cost: 0.4387534476137478
# -----Epoch 79719-----
# Theta: [-3.87321391  0.02940097  0.03927947]
# Cost: 0.43875214818221936
# -----Epoch 79720-----
# Theta: [-3.87324995  0.02940125  0.03927973]
# Cost: 0.4387508487670231
# -----Epoch 79721-----
# Theta: [-3.873286    0.02940153  0.03928   ]
# Cost: 0.43874954936815885
# -----Epoch 79722-----
# Theta: [-3.87332204  0.02940182  0.03928027]
# Cost: 0.43874824998562617
# -----Epoch 79723-----
# Theta: [-3.87335809  0.0294021   0.03928054]
# Cost: 0.43874695061942487
# -----Epoch 79724-----
# Theta: [-3.87339413  0.02940238  0.03928081]
# Cost: 0.4387456512695545
# -----Epoch 79725-----
# Theta: [-3.87343017  0.02940266  0.03928107]
# Cost: 0.4387443519360151
# -----Epoch 79726-----
# Theta: [-3.87346622  0.02940294  0.03928134]
# Cost: 0.43874305261880614
# -----Epoch 79727-----
# Theta: [-3.87350226  0.02940323  0.03928161]
# Cost: 0.43874175331792725
# -----Epoch 79728-----
# Theta: [-3.87353831  0.02940351  0.03928188]
# Cost: 0.43874045403337836
# -----Epoch 79729-----
# Theta: [-3.87357435  0.02940379  0.03928215]
# Cost: 0.4387391547651591
# -----Epoch 79730-----
# Theta: [-3.87361039  0.02940407  0.03928241]
# Cost: 0.4387378555132692
# -----Epoch 79731-----
# Theta: [-3.87364643  0.02940435  0.03928268]
# Cost: 0.4387365562777083
# -----Epoch 79732-----
# Theta: [-3.87368248  0.02940464  0.03928295]
# Cost: 0.43873525705847627
# -----Epoch 79733-----
# Theta: [-3.87371852  0.02940492  0.03928322]
# Cost: 0.4387339578555727
# -----Epoch 79734-----
# Theta: [-3.87375456  0.0294052   0.03928349]
# Cost: 0.4387326586689973
# -----Epoch 79735-----
# Theta: [-3.8737906   0.02940548  0.03928375]
# Cost: 0.43873135949874986
# -----Epoch 79736-----
# Theta: [-3.87382665  0.02940576  0.03928402]
# Cost: 0.4387300603448299
# -----Epoch 79737-----
# Theta: [-3.87386269  0.02940605  0.03928429]
# Cost: 0.43872876120723747
# -----Epoch 79738-----
# Theta: [-3.87389873  0.02940633  0.03928456]
# Cost: 0.438727462085972
# -----Epoch 79739-----
# Theta: [-3.87393477  0.02940661  0.03928483]
# Cost: 0.4387261629810333
# -----Epoch 79740-----
# Theta: [-3.87397081  0.02940689  0.0392851 ]
# Cost: 0.4387248638924211
# -----Epoch 79741-----
# Theta: [-3.87400685  0.02940717  0.03928536]
# Cost: 0.4387235648201351
# -----Epoch 79742-----
# Theta: [-3.87404289  0.02940746  0.03928563]
# Cost: 0.43872226576417506
# -----Epoch 79743-----
# Theta: [-3.87407893  0.02940774  0.0392859 ]
# Cost: 0.43872096672454064
# -----Epoch 79744-----
# Theta: [-3.87411497  0.02940802  0.03928617]
# Cost: 0.43871966770123144
# -----Epoch 79745-----
# Theta: [-3.87415101  0.0294083   0.03928644]
# Cost: 0.4387183686942474
# -----Epoch 79746-----
# Theta: [-3.87418705  0.02940858  0.0392867 ]
# Cost: 0.4387170697035881
# -----Epoch 79747-----
# Theta: [-3.87422309  0.02940887  0.03928697]
# Cost: 0.43871577072925333
# -----Epoch 79748-----
# Theta: [-3.87425913  0.02940915  0.03928724]
# Cost: 0.4387144717712428
# -----Epoch 79749-----
# Theta: [-3.87429517  0.02940943  0.03928751]
# Cost: 0.4387131728295559
# -----Epoch 79750-----
# Theta: [-3.87433121  0.02940971  0.03928778]
# Cost: 0.4387118739041929
# -----Epoch 79751-----
# Theta: [-3.87436724  0.02940999  0.03928804]
# Cost: 0.4387105749951532
# -----Epoch 79752-----
# Theta: [-3.87440328  0.02941028  0.03928831]
# Cost: 0.4387092761024365
# -----Epoch 79753-----
# Theta: [-3.87443932  0.02941056  0.03928858]
# Cost: 0.43870797722604266
# -----Epoch 79754-----
# Theta: [-3.87447536  0.02941084  0.03928885]
# Cost: 0.43870667836597116
# -----Epoch 79755-----
# Theta: [-3.8745114   0.02941112  0.03928912]
# Cost: 0.4387053795222219
# -----Epoch 79756-----
# Theta: [-3.87454743  0.0294114   0.03928938]
# Cost: 0.4387040806947946
# -----Epoch 79757-----
# Theta: [-3.87458347  0.02941169  0.03928965]
# Cost: 0.4387027818836889
# -----Epoch 79758-----
# Theta: [-3.87461951  0.02941197  0.03928992]
# Cost: 0.43870148308890455
# -----Epoch 79759-----
# Theta: [-3.87465554  0.02941225  0.03929019]
# Cost: 0.4387001843104413
# -----Epoch 79760-----
# Theta: [-3.87469158  0.02941253  0.03929046]
# Cost: 0.4386988855482987
# -----Epoch 79761-----
# Theta: [-3.87472762  0.02941281  0.03929072]
# Cost: 0.43869758680247667
# -----Epoch 79762-----
# Theta: [-3.87476365  0.02941309  0.03929099]
# Cost: 0.43869628807297495
# -----Epoch 79763-----
# Theta: [-3.87479969  0.02941338  0.03929126]
# Cost: 0.43869498935979295
# -----Epoch 79764-----
# Theta: [-3.87483572  0.02941366  0.03929153]
# Cost: 0.43869369066293057
# -----Epoch 79765-----
# Theta: [-3.87487176  0.02941394  0.0392918 ]
# Cost: 0.43869239198238774
# -----Epoch 79766-----
# Theta: [-3.87490779  0.02941422  0.03929207]
# Cost: 0.43869109331816375
# -----Epoch 79767-----
# Theta: [-3.87494383  0.0294145   0.03929233]
# Cost: 0.4386897946702586
# -----Epoch 79768-----
# Theta: [-3.87497986  0.02941479  0.0392926 ]
# Cost: 0.4386884960386719
# -----Epoch 79769-----
# Theta: [-3.8750159   0.02941507  0.03929287]
# Cost: 0.43868719742340345
# -----Epoch 79770-----
# Theta: [-3.87505193  0.02941535  0.03929314]
# Cost: 0.43868589882445286
# -----Epoch 79771-----
# Theta: [-3.87508796  0.02941563  0.03929341]
# Cost: 0.43868460024181993
# -----Epoch 79772-----
# Theta: [-3.875124    0.02941591  0.03929367]
# Cost: 0.4386833016755043
# -----Epoch 79773-----
# Theta: [-3.87516003  0.0294162   0.03929394]
# Cost: 0.43868200312550576
# -----Epoch 79774-----
# Theta: [-3.87519606  0.02941648  0.03929421]
# Cost: 0.43868070459182396
# -----Epoch 79775-----
# Theta: [-3.8752321   0.02941676  0.03929448]
# Cost: 0.43867940607445866
# -----Epoch 79776-----
# Theta: [-3.87526813  0.02941704  0.03929475]
# Cost: 0.4386781075734096
# -----Epoch 79777-----
# Theta: [-3.87530416  0.02941732  0.03929501]
# Cost: 0.43867680908867634
# -----Epoch 79778-----
# Theta: [-3.87534019  0.02941761  0.03929528]
# Cost: 0.4386755106202587
# -----Epoch 79779-----
# Theta: [-3.87537623  0.02941789  0.03929555]
# Cost: 0.4386742121681566
# -----Epoch 79780-----
# Theta: [-3.87541226  0.02941817  0.03929582]
# Cost: 0.4386729137323695
# -----Epoch 79781-----
# Theta: [-3.87544829  0.02941845  0.03929609]
# Cost: 0.438671615312897
# -----Epoch 79782-----
# Theta: [-3.87548432  0.02941873  0.03929635]
# Cost: 0.438670316909739
# -----Epoch 79783-----
# Theta: [-3.87552035  0.02941902  0.03929662]
# Cost: 0.4386690185228954
# -----Epoch 79784-----
# Theta: [-3.87555638  0.0294193   0.03929689]
# Cost: 0.43866772015236544
# -----Epoch 79785-----
# Theta: [-3.87559241  0.02941958  0.03929716]
# Cost: 0.4386664217981493
# -----Epoch 79786-----
# Theta: [-3.87562844  0.02941986  0.03929743]
# Cost: 0.43866512346024644
# -----Epoch 79787-----
# Theta: [-3.87566447  0.02942014  0.03929769]
# Cost: 0.43866382513865665
# -----Epoch 79788-----
# Theta: [-3.8757005   0.02942042  0.03929796]
# Cost: 0.4386625268333797
# -----Epoch 79789-----
# Theta: [-3.87573653  0.02942071  0.03929823]
# Cost: 0.43866122854441514
# -----Epoch 79790-----
# Theta: [-3.87577256  0.02942099  0.0392985 ]
# Cost: 0.43865993027176275
# -----Epoch 79791-----
# Theta: [-3.87580859  0.02942127  0.03929877]
# Cost: 0.4386586320154224
# -----Epoch 79792-----
# Theta: [-3.87584462  0.02942155  0.03929903]
# Cost: 0.43865733377539357
# -----Epoch 79793-----
# Theta: [-3.87588065  0.02942183  0.0392993 ]
# Cost: 0.43865603555167604
# -----Epoch 79794-----
# Theta: [-3.87591668  0.02942212  0.03929957]
# Cost: 0.4386547373442697
# -----Epoch 79795-----
# Theta: [-3.87595271  0.0294224   0.03929984]
# Cost: 0.438653439153174
# -----Epoch 79796-----
# Theta: [-3.87598874  0.02942268  0.03930011]
# Cost: 0.4386521409783889
# -----Epoch 79797-----
# Theta: [-3.87602476  0.02942296  0.03930037]
# Cost: 0.43865084281991384
# -----Epoch 79798-----
# Theta: [-3.87606079  0.02942324  0.03930064]
# Cost: 0.4386495446777489
# -----Epoch 79799-----
# Theta: [-3.87609682  0.02942353  0.03930091]
# Cost: 0.4386482465518935
# -----Epoch 79800-----
# Theta: [-3.87613285  0.02942381  0.03930118]
# Cost: 0.4386469484423474
# -----Epoch 79801-----
# Theta: [-3.87616887  0.02942409  0.03930145]
# Cost: 0.4386456503491103
# -----Epoch 79802-----
# Theta: [-3.8762049   0.02942437  0.03930171]
# Cost: 0.4386443522721821
# -----Epoch 79803-----
# Theta: [-3.87624093  0.02942465  0.03930198]
# Cost: 0.43864305421156224
# -----Epoch 79804-----
# Theta: [-3.87627695  0.02942493  0.03930225]
# Cost: 0.43864175616725076
# -----Epoch 79805-----
# Theta: [-3.87631298  0.02942522  0.03930252]
# Cost: 0.4386404581392471
# -----Epoch 79806-----
# Theta: [-3.876349    0.0294255   0.03930279]
# Cost: 0.4386391601275511
# -----Epoch 79807-----
# Theta: [-3.87638503  0.02942578  0.03930305]
# Cost: 0.43863786213216244
# -----Epoch 79808-----
# Theta: [-3.87642106  0.02942606  0.03930332]
# Cost: 0.4386365641530809
# -----Epoch 79809-----
# Theta: [-3.87645708  0.02942634  0.03930359]
# Cost: 0.4386352661903059
# -----Epoch 79810-----
# Theta: [-3.87649311  0.02942663  0.03930386]
# Cost: 0.4386339682438376
# -----Epoch 79811-----
# Theta: [-3.87652913  0.02942691  0.03930413]
# Cost: 0.4386326703136755
# -----Epoch 79812-----
# Theta: [-3.87656515  0.02942719  0.03930439]
# Cost: 0.4386313723998192
# -----Epoch 79813-----
# Theta: [-3.87660118  0.02942747  0.03930466]
# Cost: 0.4386300745022686
# -----Epoch 79814-----
# Theta: [-3.8766372   0.02942775  0.03930493]
# Cost: 0.4386287766210233
# -----Epoch 79815-----
# Theta: [-3.87667323  0.02942804  0.0393052 ]
# Cost: 0.4386274787560831
# -----Epoch 79816-----
# Theta: [-3.87670925  0.02942832  0.03930547]
# Cost: 0.4386261809074477
# -----Epoch 79817-----
# Theta: [-3.87674527  0.0294286   0.03930573]
# Cost: 0.43862488307511677
# -----Epoch 79818-----
# Theta: [-3.8767813   0.02942888  0.039306  ]
# Cost: 0.43862358525909007
# -----Epoch 79819-----
# Theta: [-3.87681732  0.02942916  0.03930627]
# Cost: 0.43862228745936716
# -----Epoch 79820-----
# Theta: [-3.87685334  0.02942944  0.03930654]
# Cost: 0.43862098967594804
# -----Epoch 79821-----
# Theta: [-3.87688937  0.02942973  0.03930681]
# Cost: 0.4386196919088321
# -----Epoch 79822-----
# Theta: [-3.87692539  0.02943001  0.03930707]
# Cost: 0.43861839415801934
# -----Epoch 79823-----
# Theta: [-3.87696141  0.02943029  0.03930734]
# Cost: 0.4386170964235094
# -----Epoch 79824-----
# Theta: [-3.87699743  0.02943057  0.03930761]
# Cost: 0.4386157987053019
# -----Epoch 79825-----
# Theta: [-3.87703345  0.02943085  0.03930788]
# Cost: 0.4386145010033966
# -----Epoch 79826-----
# Theta: [-3.87706947  0.02943114  0.03930815]
# Cost: 0.4386132033177931
# -----Epoch 79827-----
# Theta: [-3.8771055   0.02943142  0.03930841]
# Cost: 0.4386119056484914
# -----Epoch 79828-----
# Theta: [-3.87714152  0.0294317   0.03930868]
# Cost: 0.43861060799549095
# -----Epoch 79829-----
# Theta: [-3.87717754  0.02943198  0.03930895]
# Cost: 0.4386093103587916
# -----Epoch 79830-----
# Theta: [-3.87721356  0.02943226  0.03930922]
# Cost: 0.4386080127383931
# -----Epoch 79831-----
# Theta: [-3.87724958  0.02943254  0.03930948]
# Cost: 0.43860671513429506
# -----Epoch 79832-----
# Theta: [-3.8772856   0.02943283  0.03930975]
# Cost: 0.43860541754649723
# -----Epoch 79833-----
# Theta: [-3.87732162  0.02943311  0.03931002]
# Cost: 0.43860411997499926
# -----Epoch 79834-----
# Theta: [-3.87735764  0.02943339  0.03931029]
# Cost: 0.4386028224198009
# -----Epoch 79835-----
# Theta: [-3.87739366  0.02943367  0.03931056]
# Cost: 0.4386015248809019
# -----Epoch 79836-----
# Theta: [-3.87742968  0.02943395  0.03931082]
# Cost: 0.43860022735830206
# -----Epoch 79837-----
# Theta: [-3.87746569  0.02943424  0.03931109]
# Cost: 0.43859892985200094
# -----Epoch 79838-----
# Theta: [-3.87750171  0.02943452  0.03931136]
# Cost: 0.4385976323619984
# -----Epoch 79839-----
# Theta: [-3.87753773  0.0294348   0.03931163]
# Cost: 0.4385963348882939
# -----Epoch 79840-----
# Theta: [-3.87757375  0.02943508  0.0393119 ]
# Cost: 0.4385950374308875
# -----Epoch 79841-----
# Theta: [-3.87760977  0.02943536  0.03931216]
# Cost: 0.43859373998977874
# -----Epoch 79842-----
# Theta: [-3.87764579  0.02943564  0.03931243]
# Cost: 0.43859244256496716
# -----Epoch 79843-----
# Theta: [-3.8776818   0.02943593  0.0393127 ]
# Cost: 0.4385911451564528
# -----Epoch 79844-----
# Theta: [-3.87771782  0.02943621  0.03931297]
# Cost: 0.43858984776423515
# -----Epoch 79845-----
# Theta: [-3.87775384  0.02943649  0.03931324]
# Cost: 0.43858855038831407
# -----Epoch 79846-----
# Theta: [-3.87778985  0.02943677  0.0393135 ]
# Cost: 0.4385872530286891
# -----Epoch 79847-----
# Theta: [-3.87782587  0.02943705  0.03931377]
# Cost: 0.4385859556853602
# -----Epoch 79848-----
# Theta: [-3.87786189  0.02943733  0.03931404]
# Cost: 0.43858465835832683
# -----Epoch 79849-----
# Theta: [-3.8778979   0.02943762  0.03931431]
# Cost: 0.4385833610475889
# -----Epoch 79850-----
# Theta: [-3.87793392  0.0294379   0.03931458]
# Cost: 0.43858206375314596
# -----Epoch 79851-----
# Theta: [-3.87796994  0.02943818  0.03931484]
# Cost: 0.4385807664749979
# -----Epoch 79852-----
# Theta: [-3.87800595  0.02943846  0.03931511]
# Cost: 0.43857946921314417
# -----Epoch 79853-----
# Theta: [-3.87804197  0.02943874  0.03931538]
# Cost: 0.43857817196758486
# -----Epoch 79854-----
# Theta: [-3.87807798  0.02943903  0.03931565]
# Cost: 0.4385768747383194
# -----Epoch 79855-----
# Theta: [-3.878114    0.02943931  0.03931592]
# Cost: 0.43857557752534754
# -----Epoch 79856-----
# Theta: [-3.87815001  0.02943959  0.03931618]
# Cost: 0.43857428032866913
# -----Epoch 79857-----
# Theta: [-3.87818602  0.02943987  0.03931645]
# Cost: 0.4385729831482838
# -----Epoch 79858-----
# Theta: [-3.87822204  0.02944015  0.03931672]
# Cost: 0.4385716859841912
# -----Epoch 79859-----
# Theta: [-3.87825805  0.02944043  0.03931699]
# Cost: 0.438570388836391
# -----Epoch 79860-----
# Theta: [-3.87829407  0.02944072  0.03931725]
# Cost: 0.43856909170488323
# -----Epoch 79861-----
# Theta: [-3.87833008  0.029441    0.03931752]
# Cost: 0.43856779458966727
# -----Epoch 79862-----
# Theta: [-3.87836609  0.02944128  0.03931779]
# Cost: 0.438566497490743
# -----Epoch 79863-----
# Theta: [-3.87840211  0.02944156  0.03931806]
# Cost: 0.43856520040811003
# -----Epoch 79864-----
# Theta: [-3.87843812  0.02944184  0.03931833]
# Cost: 0.43856390334176826
# -----Epoch 79865-----
# Theta: [-3.87847413  0.02944213  0.03931859]
# Cost: 0.4385626062917172
# -----Epoch 79866-----
# Theta: [-3.87851014  0.02944241  0.03931886]
# Cost: 0.43856130925795667
# -----Epoch 79867-----
# Theta: [-3.87854616  0.02944269  0.03931913]
# Cost: 0.43856001224048635
# -----Epoch 79868-----
# Theta: [-3.87858217  0.02944297  0.0393194 ]
# Cost: 0.43855871523930595
# -----Epoch 79869-----
# Theta: [-3.87861818  0.02944325  0.03931967]
# Cost: 0.43855741825441524
# -----Epoch 79870-----
# Theta: [-3.87865419  0.02944353  0.03931993]
# Cost: 0.43855612128581395
# -----Epoch 79871-----
# Theta: [-3.8786902   0.02944382  0.0393202 ]
# Cost: 0.4385548243335016
# -----Epoch 79872-----
# Theta: [-3.87872621  0.0294441   0.03932047]
# Cost: 0.43855352739747816
# -----Epoch 79873-----
# Theta: [-3.87876222  0.02944438  0.03932074]
# Cost: 0.43855223047774317
# -----Epoch 79874-----
# Theta: [-3.87879823  0.02944466  0.039321  ]
# Cost: 0.4385509335742966
# -----Epoch 79875-----
# Theta: [-3.87883424  0.02944494  0.03932127]
# Cost: 0.43854963668713776
# -----Epoch 79876-----
# Theta: [-3.87887025  0.02944522  0.03932154]
# Cost: 0.4385483398162666
# -----Epoch 79877-----
# Theta: [-3.87890626  0.02944551  0.03932181]
# Cost: 0.4385470429616829
# -----Epoch 79878-----
# Theta: [-3.87894227  0.02944579  0.03932208]
# Cost: 0.43854574612338626
# -----Epoch 79879-----
# Theta: [-3.87897828  0.02944607  0.03932234]
# Cost: 0.43854444930137637
# -----Epoch 79880-----
# Theta: [-3.87901429  0.02944635  0.03932261]
# Cost: 0.43854315249565307
# -----Epoch 79881-----
# Theta: [-3.8790503   0.02944663  0.03932288]
# Cost: 0.43854185570621596
# -----Epoch 79882-----
# Theta: [-3.87908631  0.02944691  0.03932315]
# Cost: 0.4385405589330649
# -----Epoch 79883-----
# Theta: [-3.87912232  0.0294472   0.03932342]
# Cost: 0.4385392621761994
# -----Epoch 79884-----
# Theta: [-3.87915833  0.02944748  0.03932368]
# Cost: 0.4385379654356193
# -----Epoch 79885-----
# Theta: [-3.87919433  0.02944776  0.03932395]
# Cost: 0.43853666871132424
# -----Epoch 79886-----
# Theta: [-3.87923034  0.02944804  0.03932422]
# Cost: 0.43853537200331394
# -----Epoch 79887-----
# Theta: [-3.87926635  0.02944832  0.03932449]
# Cost: 0.4385340753115884
# -----Epoch 79888-----
# Theta: [-3.87930236  0.02944861  0.03932476]
# Cost: 0.43853277863614687
# -----Epoch 79889-----
# Theta: [-3.87933836  0.02944889  0.03932502]
# Cost: 0.43853148197698943
# -----Epoch 79890-----
# Theta: [-3.87937437  0.02944917  0.03932529]
# Cost: 0.43853018533411564
# -----Epoch 79891-----
# Theta: [-3.87941038  0.02944945  0.03932556]
# Cost: 0.43852888870752516
# -----Epoch 79892-----
# Theta: [-3.87944638  0.02944973  0.03932583]
# Cost: 0.4385275920972178
# -----Epoch 79893-----
# Theta: [-3.87948239  0.02945001  0.03932609]
# Cost: 0.4385262955031932
# -----Epoch 79894-----
# Theta: [-3.8795184   0.0294503   0.03932636]
# Cost: 0.4385249989254513
# -----Epoch 79895-----
# Theta: [-3.8795544   0.02945058  0.03932663]
# Cost: 0.4385237023639915
# -----Epoch 79896-----
# Theta: [-3.87959041  0.02945086  0.0393269 ]
# Cost: 0.43852240581881363
# -----Epoch 79897-----
# Theta: [-3.87962641  0.02945114  0.03932717]
# Cost: 0.43852110928991767
# -----Epoch 79898-----
# Theta: [-3.87966242  0.02945142  0.03932743]
# Cost: 0.4385198127773029
# -----Epoch 79899-----
# Theta: [-3.87969842  0.0294517   0.0393277 ]
# Cost: 0.4385185162809692
# -----Epoch 79900-----
# Theta: [-3.87973443  0.02945199  0.03932797]
# Cost: 0.4385172198009164
# -----Epoch 79901-----
# Theta: [-3.87977043  0.02945227  0.03932824]
# Cost: 0.4385159233371441
# -----Epoch 79902-----
# Theta: [-3.87980644  0.02945255  0.0393285 ]
# Cost: 0.43851462688965204
# -----Epoch 79903-----
# Theta: [-3.87984244  0.02945283  0.03932877]
# Cost: 0.43851333045844004
# -----Epoch 79904-----
# Theta: [-3.87987844  0.02945311  0.03932904]
# Cost: 0.4385120340435076
# -----Epoch 79905-----
# Theta: [-3.87991445  0.02945339  0.03932931]
# Cost: 0.4385107376448547
# -----Epoch 79906-----
# Theta: [-3.87995045  0.02945368  0.03932958]
# Cost: 0.4385094412624807
# -----Epoch 79907-----
# Theta: [-3.87998645  0.02945396  0.03932984]
# Cost: 0.4385081448963856
# -----Epoch 79908-----
# Theta: [-3.88002246  0.02945424  0.03933011]
# Cost: 0.43850684854656913
# -----Epoch 79909-----
# Theta: [-3.88005846  0.02945452  0.03933038]
# Cost: 0.43850555221303084
# -----Epoch 79910-----
# Theta: [-3.88009446  0.0294548   0.03933065]
# Cost: 0.4385042558957706
# -----Epoch 79911-----
# Theta: [-3.88013046  0.02945508  0.03933092]
# Cost: 0.4385029595947879
# -----Epoch 79912-----
# Theta: [-3.88016647  0.02945537  0.03933118]
# Cost: 0.43850166331008267
# -----Epoch 79913-----
# Theta: [-3.88020247  0.02945565  0.03933145]
# Cost: 0.43850036704165457
# -----Epoch 79914-----
# Theta: [-3.88023847  0.02945593  0.03933172]
# Cost: 0.43849907078950334
# -----Epoch 79915-----
# Theta: [-3.88027447  0.02945621  0.03933199]
# Cost: 0.43849777455362865
# -----Epoch 79916-----
# Theta: [-3.88031047  0.02945649  0.03933225]
# Cost: 0.43849647833403016
# -----Epoch 79917-----
# Theta: [-3.88034647  0.02945677  0.03933252]
# Cost: 0.4384951821307076
# -----Epoch 79918-----
# Theta: [-3.88038247  0.02945706  0.03933279]
# Cost: 0.43849388594366084
# -----Epoch 79919-----
# Theta: [-3.88041847  0.02945734  0.03933306]
# Cost: 0.4384925897728895
# -----Epoch 79920-----
# Theta: [-3.88045447  0.02945762  0.03933333]
# Cost: 0.4384912936183931
# -----Epoch 79921-----
# Theta: [-3.88049047  0.0294579   0.03933359]
# Cost: 0.4384899974801717
# -----Epoch 79922-----
# Theta: [-3.88052647  0.02945818  0.03933386]
# Cost: 0.4384887013582248
# -----Epoch 79923-----
# Theta: [-3.88056247  0.02945846  0.03933413]
# Cost: 0.4384874052525522
# -----Epoch 79924-----
# Theta: [-3.88059847  0.02945875  0.0393344 ]
# Cost: 0.43848610916315356
# -----Epoch 79925-----
# Theta: [-3.88063447  0.02945903  0.03933466]
# Cost: 0.4384848130900286
# -----Epoch 79926-----
# Theta: [-3.88067047  0.02945931  0.03933493]
# Cost: 0.4384835170331771
# -----Epoch 79927-----
# Theta: [-3.88070647  0.02945959  0.0393352 ]
# Cost: 0.4384822209925987
# -----Epoch 79928-----
# Theta: [-3.88074247  0.02945987  0.03933547]
# Cost: 0.4384809249682931
# -----Epoch 79929-----
# Theta: [-3.88077846  0.02946015  0.03933574]
# Cost: 0.43847962896026016
# -----Epoch 79930-----
# Theta: [-3.88081446  0.02946044  0.039336  ]
# Cost: 0.4384783329684995
# -----Epoch 79931-----
# Theta: [-3.88085046  0.02946072  0.03933627]
# Cost: 0.4384770369930106
# -----Epoch 79932-----
# Theta: [-3.88088646  0.029461    0.03933654]
# Cost: 0.43847574103379366
# -----Epoch 79933-----
# Theta: [-3.88092245  0.02946128  0.03933681]
# Cost: 0.438474445090848
# -----Epoch 79934-----
# Theta: [-3.88095845  0.02946156  0.03933707]
# Cost: 0.4384731491641735
# -----Epoch 79935-----
# Theta: [-3.88099445  0.02946184  0.03933734]
# Cost: 0.4384718532537698
# -----Epoch 79936-----
# Theta: [-3.88103044  0.02946213  0.03933761]
# Cost: 0.43847055735963675
# -----Epoch 79937-----
# Theta: [-3.88106644  0.02946241  0.03933788]
# Cost: 0.43846926148177395
# -----Epoch 79938-----
# Theta: [-3.88110244  0.02946269  0.03933815]
# Cost: 0.43846796562018114
# -----Epoch 79939-----
# Theta: [-3.88113843  0.02946297  0.03933841]
# Cost: 0.4384666697748581
# -----Epoch 79940-----
# Theta: [-3.88117443  0.02946325  0.03933868]
# Cost: 0.43846537394580437
# -----Epoch 79941-----
# Theta: [-3.88121042  0.02946353  0.03933895]
# Cost: 0.4384640781330199
# -----Epoch 79942-----
# Theta: [-3.88124642  0.02946382  0.03933922]
# Cost: 0.4384627823365042
# -----Epoch 79943-----
# Theta: [-3.88128241  0.0294641   0.03933948]
# Cost: 0.4384614865562572
# -----Epoch 79944-----
# Theta: [-3.88131841  0.02946438  0.03933975]
# Cost: 0.43846019079227844
# -----Epoch 79945-----
# Theta: [-3.8813544   0.02946466  0.03934002]
# Cost: 0.43845889504456753
# -----Epoch 79946-----
# Theta: [-3.8813904   0.02946494  0.03934029]
# Cost: 0.4384575993131245
# -----Epoch 79947-----
# Theta: [-3.88142639  0.02946522  0.03934056]
# Cost: 0.4384563035979488
# -----Epoch 79948-----
# Theta: [-3.88146238  0.02946551  0.03934082]
# Cost: 0.43845500789904035
# -----Epoch 79949-----
# Theta: [-3.88149838  0.02946579  0.03934109]
# Cost: 0.4384537122163987
# -----Epoch 79950-----
# Theta: [-3.88153437  0.02946607  0.03934136]
# Cost: 0.43845241655002365
# -----Epoch 79951-----
# Theta: [-3.88157036  0.02946635  0.03934163]
# Cost: 0.4384511208999149
# -----Epoch 79952-----
# Theta: [-3.88160636  0.02946663  0.03934189]
# Cost: 0.4384498252660722
# -----Epoch 79953-----
# Theta: [-3.88164235  0.02946691  0.03934216]
# Cost: 0.438448529648495
# -----Epoch 79954-----
# Theta: [-3.88167834  0.0294672   0.03934243]
# Cost: 0.43844723404718344
# -----Epoch 79955-----
# Theta: [-3.88171433  0.02946748  0.0393427 ]
# Cost: 0.4384459384621371
# -----Epoch 79956-----
# Theta: [-3.88175033  0.02946776  0.03934297]
# Cost: 0.4384446428933555
# -----Epoch 79957-----
# Theta: [-3.88178632  0.02946804  0.03934323]
# Cost: 0.43844334734083845
# -----Epoch 79958-----
# Theta: [-3.88182231  0.02946832  0.0393435 ]
# Cost: 0.43844205180458584
# -----Epoch 79959-----
# Theta: [-3.8818583   0.0294686   0.03934377]
# Cost: 0.4384407562845972
# -----Epoch 79960-----
# Theta: [-3.88189429  0.02946888  0.03934404]
# Cost: 0.43843946078087215
# -----Epoch 79961-----
# Theta: [-3.88193028  0.02946917  0.0393443 ]
# Cost: 0.43843816529341073
# -----Epoch 79962-----
# Theta: [-3.88196627  0.02946945  0.03934457]
# Cost: 0.4384368698222124
# -----Epoch 79963-----
# Theta: [-3.88200226  0.02946973  0.03934484]
# Cost: 0.438435574367277
# -----Epoch 79964-----
# Theta: [-3.88203825  0.02947001  0.03934511]
# Cost: 0.43843427892860415
# -----Epoch 79965-----
# Theta: [-3.88207424  0.02947029  0.03934537]
# Cost: 0.43843298350619364
# -----Epoch 79966-----
# Theta: [-3.88211023  0.02947057  0.03934564]
# Cost: 0.4384316881000452
# -----Epoch 79967-----
# Theta: [-3.88214622  0.02947086  0.03934591]
# Cost: 0.43843039271015843
# -----Epoch 79968-----
# Theta: [-3.88218221  0.02947114  0.03934618]
# Cost: 0.43842909733653307
# -----Epoch 79969-----
# Theta: [-3.8822182   0.02947142  0.03934645]
# Cost: 0.438427801979169
# -----Epoch 79970-----
# Theta: [-3.88225419  0.0294717   0.03934671]
# Cost: 0.4384265066380657
# -----Epoch 79971-----
# Theta: [-3.88229018  0.02947198  0.03934698]
# Cost: 0.438425211313223
# -----Epoch 79972-----
# Theta: [-3.88232617  0.02947226  0.03934725]
# Cost: 0.43842391600464076
# -----Epoch 79973-----
# Theta: [-3.88236215  0.02947255  0.03934752]
# Cost: 0.43842262071231847
# -----Epoch 79974-----
# Theta: [-3.88239814  0.02947283  0.03934778]
# Cost: 0.4384213254362559
# -----Epoch 79975-----
# Theta: [-3.88243413  0.02947311  0.03934805]
# Cost: 0.4384200301764528
# -----Epoch 79976-----
# Theta: [-3.88247012  0.02947339  0.03934832]
# Cost: 0.43841873493290895
# -----Epoch 79977-----
# Theta: [-3.88250611  0.02947367  0.03934859]
# Cost: 0.43841743970562386
# -----Epoch 79978-----
# Theta: [-3.88254209  0.02947395  0.03934886]
# Cost: 0.4384161444945976
# -----Epoch 79979-----
# Theta: [-3.88257808  0.02947423  0.03934912]
# Cost: 0.43841484929982943
# -----Epoch 79980-----
# Theta: [-3.88261407  0.02947452  0.03934939]
# Cost: 0.43841355412131944
# -----Epoch 79981-----
# Theta: [-3.88265005  0.0294748   0.03934966]
# Cost: 0.4384122589590672
# -----Epoch 79982-----
# Theta: [-3.88268604  0.02947508  0.03934993]
# Cost: 0.43841096381307243
# -----Epoch 79983-----
# Theta: [-3.88272202  0.02947536  0.03935019]
# Cost: 0.4384096686833348
# -----Epoch 79984-----
# Theta: [-3.88275801  0.02947564  0.03935046]
# Cost: 0.4384083735698542
# -----Epoch 79985-----
# Theta: [-3.88279399  0.02947592  0.03935073]
# Cost: 0.43840707847263005
# -----Epoch 79986-----
# Theta: [-3.88282998  0.02947621  0.039351  ]
# Cost: 0.43840578339166236
# -----Epoch 79987-----
# Theta: [-3.88286596  0.02947649  0.03935126]
# Cost: 0.43840448832695067
# -----Epoch 79988-----
# Theta: [-3.88290195  0.02947677  0.03935153]
# Cost: 0.43840319327849475
# -----Epoch 79989-----
# Theta: [-3.88293793  0.02947705  0.0393518 ]
# Cost: 0.4384018982462943
# -----Epoch 79990-----
# Theta: [-3.88297392  0.02947733  0.03935207]
# Cost: 0.438400603230349
# -----Epoch 79991-----
# Theta: [-3.8830099   0.02947761  0.03935234]
# Cost: 0.43839930823065876
# -----Epoch 79992-----
# Theta: [-3.88304589  0.0294779   0.0393526 ]
# Cost: 0.4383980132472231
# -----Epoch 79993-----
# Theta: [-3.88308187  0.02947818  0.03935287]
# Cost: 0.4383967182800417
# -----Epoch 79994-----
# Theta: [-3.88311785  0.02947846  0.03935314]
# Cost: 0.4383954233291144
# -----Epoch 79995-----
# Theta: [-3.88315384  0.02947874  0.03935341]
# Cost: 0.43839412839444086
# -----Epoch 79996-----
# Theta: [-3.88318982  0.02947902  0.03935367]
# Cost: 0.4383928334760208
# -----Epoch 79997-----
# Theta: [-3.8832258   0.0294793   0.03935394]
# Cost: 0.4383915385738541
# -----Epoch 79998-----
# Theta: [-3.88326178  0.02947958  0.03935421]
# Cost: 0.4383902436879401
# -----Epoch 79999-----
# Theta: [-3.88329777  0.02947987  0.03935448]
# Cost: 0.43838894881827895

# %%
# Draw Decision Boundary Here

def plotDecisionBoundary(theta, X, Y):
    plotData(X[:,1:], Y)
#     # get min and max values
    xx = [np.min(X[:, 1]), np.max(X[:, 2])]
#     # get boundary of separation
    yy =  - (theta[0] + np.dot(theta[1], xx)) / theta[2]
    # Derive it from "theta[0]+yy*theta[1]+xx*theta[2]=0" THINK ABOUT THE REASON.
    plt.plot(xx, yy, label='Decision Boundary')
    plt.legend()
    plt.show()

plotDecisionBoundary(theta, x, y)

# %% [markdown]
# ### 1.6 Evaluating Logistic Regression
#
# Evaluate the model with given data. **(10 Points)**
#
# **Tasks:**
# 1. Calculate the training accuracy and **PRINT IT OUT**.
# 2. Evaluate the predicted probability of the learnt model with x1 = 56 and x2 = 32 and **PRINT IT OUT**.
#
#
# **Hints:**
# 1. Positive(prediction>0.5) and negative(prediction<=0.5).
# 2. The prediction results are based on acceptance probability. Given the two exam scores, we expected the model yields either high probability of "fail" or low probability of "pass".
# 3. Training accuracy should be around **85%**.

# %%
### Evaluate the model

def predict(X):
    return sigmoid(np.dot(X, theta))

def accuracy(X, actual_classes, probab_threshold=0.5):
    predicted_classes = (predict(X) >= probab_threshold).astype(int)
    predicted_classes = predicted_classes.flatten()
    accuracy = np.mean(predicted_classes == actual_classes)
    return accuracy * 100


### Get training accuracy
print('Training Accuracy: {0}'.format(accuracy(x, y)))

### Get predicted probability
print ('Probablity of acceptance for exam 1 score: {0} and exam 2 score: {1} is {2} percent.'.format(56, 32, predict([1,56,32])))
# Out:
# Training Accuracy: 85.0
# Probablity of acceptance for exam 1 score: 56 and exam 2 score: 32 is 0.2742666161817614 percent.

# %% [markdown]
# ### 1.7 - Cost function and gradient with regularization
#
# Implement the cost function and gradient for regularized logistic regression. **(10 points)**
#
# **Tasks:**
# 1. Implement the "cal_reg_cost" to compute the cost.
# 2. Implement the "cal_reg_grad" to compute the gradients.
# 3. Test the the two functions with initial values.
#
# **Hint:**
# 1. The regularized cost function in logistic regression is similar to the previous one, but with a regularization term.
# ![image.png](data:image/png;base64,...)
# 2. The gradient of the cost is a vector of the same length as θ where the $j$th element (for $j = 0, 1, . . . , n)$ is defined as follows. Here, the first constant term will not be regularized. The reason could be found in ***The Elements of Statistical Learning by Hastie et al. (P.63-64)*** if you are curious.
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)
#
# 3. Use **eps = 1e-15** to prevent divide by 0 exception. Set regularization parameter **lam** to **1** and **zero out**
# the first lam; think about the reason.
#
#     def cal_reg_cost(theta, X, y, lam):
#         htheta = ...
#         term1 = ...
#         term2 = ...
#         term3 =  ...
#         J = - 1 / m * (term1 + term2 - term3)
#
#         return cost
#
#     def cal_reg_grad(theta, X, y, lam):
#
#         htheta = ...
#         term1 = ...
#         term2 = ...
#         grad = 1 / m * (term1 + term2)
#
#         return grad
#
#
# 5. Initialize the intercept term (constant term) with **ones** and the theta with **zeros**. Test the functions with these initial values, which should be the same as the ones in section 1.4.\
#     **Expected outputs:**\
#     Cost at initial theta : 0.6931471805599445\
#     Gradient at inital theta : [-0.1        -10.91242026 -11.73652937]

# %%
### Implement the cost function here

def cal_reg_cost(theta, X, y, lam):
    m = X.shape[0]
#     # make an array of lambdas 
    lamarray = np.ones(len(theta)) * lam
    
#     # zero out first element so se don't regularize constant term; think about the reason.
    lamarray[0] = 0.0
    eps = 1e-15

#     # compute the hypothesis
    htheta = sigmoid(np.dot(X, theta))
        
#     # compute J in three terms
    term1 = np.dot(np.log(htheta), y)
    term2 = np.dot(np.log(1-htheta-eps), 1-y)
    term3 = np.dot((lamarray/(2*m)), theta**2)

#     # cost function
    J = - (1 / m) * np.sum(term1 + term2) - term3 
    
    return J

############################################
def cal_reg_grad(theta, X, y, lam):

    lamarray = np.ones(len(theta)) * lam
#     # zero out first element ; think about the reason.
    lamarray[0] = 0.0

#     # compute the hypothesis
    htheta = sigmoid(np.dot(X, theta))
    
#     # gradient
    grad = cal_grad(theta, X, y) + np.sum(lamarray/m * theta**2)
            
    return grad
    

#########################################################
# # initalize theta
initial_theta = np.zeros(n+1)

# # set regularization parameter to 1
lam = 1

# # compute and display initial cost and gradient
J = cal_reg_cost(initial_theta, x, y, lam)
grad = cal_reg_grad(initial_theta, x, y, lam)
print ('Cost at initial theta: {0}'.format(J))
print ('Gradient at inital theta:\n {0}'.format(grad))
# Out:
# Cost at initial theta: 0.6931471805599462
# Gradient at inital theta:
#  [ -0.1        -10.91242026 -11.73652937]

# %% [markdown]
# ## 1.8 Train parameters with Gradient Descent ##
#
#
# Train parameters with Gradient Descent. **(10 Points)**
#
# **Tasks:**
# 1. Implement GD function to optimize parameters.
# 2. **Calculate best fit theta** by Gradient Descent with learning rate of **0.001 (1e-3)**, epoch of **80K**, and lambda **1**.
# 3. **PRINT OUT** the best theta (the last one is considered as the best here) and its corresponding cost.
#
# **Hints:**
# 1. The initial theta from above blocks is used as initial values.
# 2. Validation results for first 5 epochs:\
# ------Epoch 0------\
# Best fit theta: \
# [0.0001     0.01091242 0.01173653]\
# Cost function at best fit theta: 0.6996134129049489\
# ------Epoch 1------\
# Best fit theta:\
# [-0.0001129   0.00053935  0.00229338]\
# Cost function at best fit theta: 0.6649354888127291\
# ------Epoch 2------\
# Best fit theta: \
# [-5.93558681e-05  8.33163330e-03  1.07755735e-02]\
# Cost function at best fit theta: 0.667994967854362\
# ------Epoch 3------\
# Best fit theta: \
# [-0.0002356   0.00046054  0.00370807]\
# Cost function at best fit theta: 0.6545900033839479\
# ------Epoch 4------\
# Best fit theta: \
# [-0.00020362  0.00683253  0.01065154]\
# Cost function at best fit theta: 0.656333864181721
#
# 3. It may take less than 1 min to finish running.

# %%
# Learning and print the result here

theta = initial_theta
lr = 1e-3
lam = 1

for epoch in range(80000):
    J = cal_reg_cost(theta, x, y, lam)
    grad = cal_reg_grad(theta, x, y, lam)
    theta = theta - np.dot(lr, grad) # parameter update rule of gradient descent
    print('------Epoch {0}------'.format(epoch))
    print('Best fit theta: {0}'.format(theta))
    print('Cost function at best fit theta: {0}'.format(cal_reg_cost(theta, x, y, lam)))
# Out:
# st function at best fit theta: 0.43883842844579696
# ------Epoch 79617------
# Best fit theta: [-3.87044046  0.02937926  0.03925881]
# Cost function at best fit theta: 0.4388371264543012
# ------Epoch 79618------
# Best fit theta: [-3.87047655  0.02937954  0.03925908]
# Cost function at best fit theta: 0.4388358244791624
# ------Epoch 79619------
# Best fit theta: [-3.87051264  0.02937982  0.03925935]
# Cost function at best fit theta: 0.43883452252038063
# ------Epoch 79620------
# Best fit theta: [-3.87054873  0.02938011  0.03925962]
# Cost function at best fit theta: 0.43883322057795543
# ------Epoch 79621------
# Best fit theta: [-3.87058483  0.02938039  0.03925988]
# Cost function at best fit theta: 0.43883191865188653
# ------Epoch 79622------
# Best fit theta: [-3.87062092  0.02938067  0.03926015]
# Cost function at best fit theta: 0.43883061674217366
# ------Epoch 79623------
# Best fit theta: [-3.87065701  0.02938095  0.03926042]
# Cost function at best fit theta: 0.4388293148488165
# ------Epoch 79624------
# Best fit theta: [-3.8706931   0.02938124  0.03926069]
# Cost function at best fit theta: 0.4388280129718147
# ------Epoch 79625------
# Best fit theta: [-3.87072919  0.02938152  0.03926096]
# Cost function at best fit theta: 0.4388267111111682
# ------Epoch 79626------
# Best fit theta: [-3.87076528  0.0293818   0.03926123]
# Cost function at best fit theta: 0.43882540926687646
# ------Epoch 79627------
# Best fit theta: [-3.87080137  0.02938208  0.03926149]
# Cost function at best fit theta: 0.4388241074389394
# ------Epoch 79628------
# Best fit theta: [-3.87083746  0.02938237  0.03926176]
# Cost function at best fit theta: 0.4388228056273564
# ------Epoch 79629------
# Best fit theta: [-3.87087355  0.02938265  0.03926203]
# Cost function at best fit theta: 0.4388215038321276
# ------Epoch 79630------
# Best fit theta: [-3.87090964  0.02938293  0.0392623 ]
# Cost function at best fit theta: 0.43882020205325256
# ------Epoch 79631------
# Best fit theta: [-3.87094573  0.02938321  0.03926257]
# Cost function at best fit theta: 0.43881890029073095
# ------Epoch 79632------
# Best fit theta: [-3.87098182  0.0293835   0.03926284]
# Cost function at best fit theta: 0.4388175985445623
# ------Epoch 79633------
# Best fit theta: [-3.87101791  0.02938378  0.03926311]
# Cost function at best fit theta: 0.43881629681474665
# ------Epoch 79634------
# Best fit theta: [-3.871054    0.02938406  0.03926337]
# Cost function at best fit theta: 0.4388149951012836
# ------Epoch 79635------
# Best fit theta: [-3.87109009  0.02938434  0.03926364]
# Cost function at best fit theta: 0.4388136934041728
# ------Epoch 79636------
# Best fit theta: [-3.87112617  0.02938462  0.03926391]
# Cost function at best fit theta: 0.438812391723414
# ------Epoch 79637------
# Best fit theta: [-3.87116226  0.02938491  0.03926418]
# Cost function at best fit theta: 0.438811090059007
# ------Epoch 79638------
# Best fit theta: [-3.87119835  0.02938519  0.03926445]
# Cost function at best fit theta: 0.4388097884109513
# ------Epoch 79639------
# Best fit theta: [-3.87123444  0.02938547  0.03926472]
# Cost function at best fit theta: 0.43880848677924683
# ------Epoch 79640------
# Best fit theta: [-3.87127053  0.02938575  0.03926498]
# Cost function at best fit theta: 0.4388071851638931
# ------Epoch 79641------
# Best fit theta: [-3.87130661  0.02938604  0.03926525]
# Cost function at best fit theta: 0.4388058835648901
# ------Epoch 79642------
# Best fit theta: [-3.8713427   0.02938632  0.03926552]
# Cost function at best fit theta: 0.4388045819822373
# ------Epoch 79643------
# Best fit theta: [-3.87137879  0.0293866   0.03926579]
# Cost function at best fit theta: 0.4388032804159344
# ------Epoch 79644------
# Best fit theta: [-3.87141487  0.02938688  0.03926606]
# Cost function at best fit theta: 0.4388019788659814
# ------Epoch 79645------
# Best fit theta: [-3.87145096  0.02938717  0.03926633]
# Cost function at best fit theta: 0.4388006773323778
# ------Epoch 79646------
# Best fit theta: [-3.87148705  0.02938745  0.03926659]
# Cost function at best fit theta: 0.4387993758151233
# ------Epoch 79647------
# Best fit theta: [-3.87152313  0.02938773  0.03926686]
# Cost function at best fit theta: 0.4387980743142175
# ------Epoch 79648------
# Best fit theta: [-3.87155922  0.02938801  0.03926713]
# Cost function at best fit theta: 0.4387967728296605
# ------Epoch 79649------
# Best fit theta: [-3.8715953   0.02938829  0.0392674 ]
# Cost function at best fit theta: 0.4387954713614517
# ------Epoch 79650------
# Best fit theta: [-3.87163139  0.02938858  0.03926767]
# Cost function at best fit theta: 0.4387941699095908
# ------Epoch 79651------
# Best fit theta: [-3.87166747  0.02938886  0.03926794]
# Cost function at best fit theta: 0.4387928684740778
# ------Epoch 79652------
# Best fit theta: [-3.87170356  0.02938914  0.03926821]
# Cost function at best fit theta: 0.4387915670549121
# ------Epoch 79653------
# Best fit theta: [-3.87173964  0.02938942  0.03926847]
# Cost function at best fit theta: 0.4387902656520935
# ------Epoch 79654------
# Best fit theta: [-3.87177573  0.02938971  0.03926874]
# Cost function at best fit theta: 0.43878896426562186
# ------Epoch 79655------
# Best fit theta: [-3.87181181  0.02938999  0.03926901]
# Cost function at best fit theta: 0.4387876628954967
# ------Epoch 79656------
# Best fit theta: [-3.87184789  0.02939027  0.03926928]
# Cost function at best fit theta: 0.43878636154171785
# ------Epoch 79657------
# Best fit theta: [-3.87188398  0.02939055  0.03926955]
# Cost function at best fit theta: 0.4387850602042849
# ------Epoch 79658------
# Best fit theta: [-3.87192006  0.02939084  0.03926982]
# Cost function at best fit theta: 0.43878375888319776
# ------Epoch 79659------
# Best fit theta: [-3.87195614  0.02939112  0.03927008]
# Cost function at best fit theta: 0.438782457578456
# ------Epoch 79660------
# Best fit theta: [-3.87199223  0.0293914   0.03927035]
# Cost function at best fit theta: 0.43878115629005937
# ------Epoch 79661------
# Best fit theta: [-3.87202831  0.02939168  0.03927062]
# Cost function at best fit theta: 0.43877985501800754
# ------Epoch 79662------
# Best fit theta: [-3.87206439  0.02939196  0.03927089]
# Cost function at best fit theta: 0.43877855376230035
# ------Epoch 79663------
# Best fit theta: [-3.87210047  0.02939225  0.03927116]
# Cost function at best fit theta: 0.43877725252293737
# ------Epoch 79664------
# Best fit theta: [-3.87213656  0.02939253  0.03927143]
# Cost function at best fit theta: 0.4387759512999184
# ------Epoch 79665------
# Best fit theta: [-3.87217264  0.02939281  0.03927169]
# Cost function at best fit theta: 0.4387746500932431
# ------Epoch 79666------
# Best fit theta: [-3.87220872  0.02939309  0.03927196]
# Cost function at best fit theta: 0.43877334890291125
# ------Epoch 79667------
# Best fit theta: [-3.8722448   0.02939338  0.03927223]
# Cost function at best fit theta: 0.4387720477289225
# ------Epoch 79668------
# Best fit theta: [-3.87228088  0.02939366  0.0392725 ]
# Cost function at best fit theta: 0.4387707465712767
# ------Epoch 79669------
# Best fit theta: [-3.87231696  0.02939394  0.03927277]
# Cost function at best fit theta: 0.43876944542997326
# ------Epoch 79670------
# Best fit theta: [-3.87235304  0.02939422  0.03927304]
# Cost function at best fit theta: 0.4387681443050121
# ------Epoch 79671------
# Best fit theta: [-3.87238912  0.02939451  0.0392733 ]
# Cost function at best fit theta: 0.43876684319639303
# ------Epoch 79672------
# Best fit theta: [-3.8724252   0.02939479  0.03927357]
# Cost function at best fit theta: 0.4387655421041157
# ------Epoch 79673------
# Best fit theta: [-3.87246128  0.02939507  0.03927384]
# Cost function at best fit theta: 0.43876424102817974
# ------Epoch 79674------
# Best fit theta: [-3.87249736  0.02939535  0.03927411]
# Cost function at best fit theta: 0.43876293996858484
# ------Epoch 79675------
# Best fit theta: [-3.87253344  0.02939563  0.03927438]
# Cost function at best fit theta: 0.4387616389253308
# ------Epoch 79676------
# Best fit theta: [-3.87256952  0.02939592  0.03927465]
# Cost function at best fit theta: 0.43876033789841734
# ------Epoch 79677------
# Best fit theta: [-3.8726056   0.0293962   0.03927492]
# Cost function at best fit theta: 0.43875903688784407
# ------Epoch 79678------
# Best fit theta: [-3.87264168  0.02939648  0.03927518]
# Cost function at best fit theta: 0.43875773589361095
# ------Epoch 79679------
# Best fit theta: [-3.87267776  0.02939676  0.03927545]
# Cost function at best fit theta: 0.43875643491571736
# ------Epoch 79680------
# Best fit theta: [-3.87271384  0.02939705  0.03927572]
# Cost function at best fit theta: 0.4387551339541632
# ------Epoch 79681------
# Best fit theta: [-3.87274991  0.02939733  0.03927599]
# Cost function at best fit theta: 0.43875383300894827
# ------Epoch 79682------
# Best fit theta: [-3.87278599  0.02939761  0.03927626]
# Cost function at best fit theta: 0.43875253208007203
# ------Epoch 79683------
# Best fit theta: [-3.87282207  0.02939789  0.03927653]
# Cost function at best fit theta: 0.4387512311675344
# ------Epoch 79684------
# Best fit theta: [-3.87285815  0.02939817  0.03927679]
# Cost function at best fit theta: 0.4387499302713351
# ------Epoch 79685------
# Best fit theta: [-3.87289422  0.02939846  0.03927706]
# Cost function at best fit theta: 0.43874862939147363
# ------Epoch 79686------
# Best fit theta: [-3.8729303   0.02939874  0.03927733]
# Cost function at best fit theta: 0.4387473285279499
# ------Epoch 79687------
# Best fit theta: [-3.87296638  0.02939902  0.0392776 ]
# Cost function at best fit theta: 0.43874602768076365
# ------Epoch 79688------
# Best fit theta: [-3.87300245  0.0293993   0.03927787]
# Cost function at best fit theta: 0.43874472684991456
# ------Epoch 79689------
# Best fit theta: [-3.87303853  0.02939959  0.03927814]
# Cost function at best fit theta: 0.4387434260354022
# ------Epoch 79690------
# Best fit theta: [-3.87307461  0.02939987  0.0392784 ]
# Cost function at best fit theta: 0.43874212523722633
# ------Epoch 79691------
# Best fit theta: [-3.87311068  0.02940015  0.03927867]
# Cost function at best fit theta: 0.4387408244553867
# ------Epoch 79692------
# Best fit theta: [-3.87314676  0.02940043  0.03927894]
# Cost function at best fit theta: 0.4387395236898831
# ------Epoch 79693------
# Best fit theta: [-3.87318283  0.02940071  0.03927921]
# Cost function at best fit theta: 0.4387382229407152
# ------Epoch 79694------
# Best fit theta: [-3.87321891  0.029401    0.03927948]
# Cost function at best fit theta: 0.4387369222078828
# ------Epoch 79695------
# Best fit theta: [-3.87325498  0.02940128  0.03927975]
# Cost function at best fit theta: 0.43873562149138534
# ------Epoch 79696------
# Best fit theta: [-3.87329106  0.02940156  0.03928001]
# Cost function at best fit theta: 0.4387343207912229
# ------Epoch 79697------
# Best fit theta: [-3.87332713  0.02940184  0.03928028]
# Cost function at best fit theta: 0.43873302010739484
# ------Epoch 79698------
# Best fit theta: [-3.87336321  0.02940213  0.03928055]
# Cost function at best fit theta: 0.43873171943990097
# ------Epoch 79699------
# Best fit theta: [-3.87339928  0.02940241  0.03928082]
# Cost function at best fit theta: 0.43873041878874125
# ------Epoch 79700------
# Best fit theta: [-3.87343536  0.02940269  0.03928109]
# Cost function at best fit theta: 0.4387291181539152
# ------Epoch 79701------
# Best fit theta: [-3.87347143  0.02940297  0.03928136]
# Cost function at best fit theta: 0.43872781753542245
# ------Epoch 79702------
# Best fit theta: [-3.8735075   0.02940325  0.03928162]
# Cost function at best fit theta: 0.43872651693326287
# ------Epoch 79703------
# Best fit theta: [-3.87354358  0.02940354  0.03928189]
# Cost function at best fit theta: 0.4387252163474361
# ------Epoch 79704------
# Best fit theta: [-3.87357965  0.02940382  0.03928216]
# Cost function at best fit theta: 0.43872391577794184
# ------Epoch 79705------
# Best fit theta: [-3.87361572  0.0294041   0.03928243]
# Cost function at best fit theta: 0.43872261522478007
# ------Epoch 79706------
# Best fit theta: [-3.87365179  0.02940438  0.0392827 ]
# Cost function at best fit theta: 0.4387213146879499
# ------Epoch 79707------
# Best fit theta: [-3.87368787  0.02940467  0.03928297]
# Cost function at best fit theta: 0.4387200141674516
# ------Epoch 79708------
# Best fit theta: [-3.87372394  0.02940495  0.03928323]
# Cost function at best fit theta: 0.4387187136632847
# ------Epoch 79709------
# Best fit theta: [-3.87376001  0.02940523  0.0392835 ]
# Cost function at best fit theta: 0.43871741317544893
# ------Epoch 79710------
# Best fit theta: [-3.87379608  0.02940551  0.03928377]
# Cost function at best fit theta: 0.4387161127039439
# ------Epoch 79711------
# Best fit theta: [-3.87383215  0.02940579  0.03928404]
# Cost function at best fit theta: 0.43871481224876946
# ------Epoch 79712------
# Best fit theta: [-3.87386822  0.02940608  0.03928431]
# Cost function at best fit theta: 0.4387135118099253
# ------Epoch 79713------
# Best fit theta: [-3.87390429  0.02940636  0.03928458]
# Cost function at best fit theta: 0.438712211387411
# ------Epoch 79714------
# Best fit theta: [-3.87394037  0.02940664  0.03928484]
# Cost function at best fit theta: 0.43871091098122644
# ------Epoch 79715------
# Best fit theta: [-3.87397644  0.02940692  0.03928511]
# Cost function at best fit theta: 0.43870961059137137
# ------Epoch 79716------
# Best fit theta: [-3.87401251  0.02940721  0.03928538]
# Cost function at best fit theta: 0.4387083102178453
# ------Epoch 79717------
# Best fit theta: [-3.87404858  0.02940749  0.03928565]
# Cost function at best fit theta: 0.43870700986064803
# ------Epoch 79718------
# Best fit theta: [-3.87408465  0.02940777  0.03928592]
# Cost function at best fit theta: 0.4387057095197794
# ------Epoch 79719------
# Best fit theta: [-3.87412072  0.02940805  0.03928619]
# Cost function at best fit theta: 0.4387044091952389
# ------Epoch 79720------
# Best fit theta: [-3.87415678  0.02940833  0.03928645]
# Cost function at best fit theta: 0.43870310888702646
# ------Epoch 79721------
# Best fit theta: [-3.87419285  0.02940862  0.03928672]
# Cost function at best fit theta: 0.4387018085951417
# ------Epoch 79722------
# Best fit theta: [-3.87422892  0.0294089   0.03928699]
# Cost function at best fit theta: 0.43870050831958424
# ------Epoch 79723------
# Best fit theta: [-3.87426499  0.02940918  0.03928726]
# Cost function at best fit theta: 0.4386992080603539
# ------Epoch 79724------
# Best fit theta: [-3.87430106  0.02940946  0.03928753]
# Cost function at best fit theta: 0.43869790781745044
# ------Epoch 79725------
# Best fit theta: [-3.87433713  0.02940975  0.0392878 ]
# Cost function at best fit theta: 0.43869660759087353
# ------Epoch 79726------
# Best fit theta: [-3.8743732   0.02941003  0.03928806]
# Cost function at best fit theta: 0.43869530738062285
# ------Epoch 79727------
# Best fit theta: [-3.87440926  0.02941031  0.03928833]
# Cost function at best fit theta: 0.43869400718669804
# ------Epoch 79728------
# Best fit theta: [-3.87444533  0.02941059  0.0392886 ]
# Cost function at best fit theta: 0.43869270700909907
# ------Epoch 79729------
# Best fit theta: [-3.8744814   0.02941087  0.03928887]
# Cost function at best fit theta: 0.43869140684782537
# ------Epoch 79730------
# Best fit theta: [-3.87451746  0.02941116  0.03928914]
# Cost function at best fit theta: 0.4386901067028769
# ------Epoch 79731------
# Best fit theta: [-3.87455353  0.02941144  0.0392894 ]
# Cost function at best fit theta: 0.43868880657425313
# ------Epoch 79732------
# Best fit theta: [-3.8745896   0.02941172  0.03928967]
# Cost function at best fit theta: 0.4386875064619538
# ------Epoch 79733------
# Best fit theta: [-3.87462566  0.029412    0.03928994]
# Cost function at best fit theta: 0.4386862063659789
# ------Epoch 79734------
# Best fit theta: [-3.87466173  0.02941229  0.03929021]
# Cost function at best fit theta: 0.43868490628632795
# ------Epoch 79735------
# Best fit theta: [-3.8746978   0.02941257  0.03929048]
# Cost function at best fit theta: 0.4386836062230006
# ------Epoch 79736------
# Best fit theta: [-3.87473386  0.02941285  0.03929075]
# Cost function at best fit theta: 0.43868230617599674
# ------Epoch 79737------
# Best fit theta: [-3.87476993  0.02941313  0.03929101]
# Cost function at best fit theta: 0.43868100614531585
# ------Epoch 79738------
# Best fit theta: [-3.87480599  0.02941341  0.03929128]
# Cost function at best fit theta: 0.4386797061309579
# ------Epoch 79739------
# Best fit theta: [-3.87484206  0.0294137   0.03929155]
# Cost function at best fit theta: 0.43867840613292236
# ------Epoch 79740------
# Best fit theta: [-3.87487812  0.02941398  0.03929182]
# Cost function at best fit theta: 0.43867710615120914
# ------Epoch 79741------
# Best fit theta: [-3.87491419  0.02941426  0.03929209]
# Cost function at best fit theta: 0.43867580618581803
# ------Epoch 79742------
# Best fit theta: [-3.87495025  0.02941454  0.03929236]
# Cost function at best fit theta: 0.4386745062367484
# ------Epoch 79743------
# Best fit theta: [-3.87498632  0.02941482  0.03929262]
# Cost function at best fit theta: 0.43867320630400014
# ------Epoch 79744------
# Best fit theta: [-3.87502238  0.02941511  0.03929289]
# Cost function at best fit theta: 0.4386719063875731
# ------Epoch 79745------
# Best fit theta: [-3.87505844  0.02941539  0.03929316]
# Cost function at best fit theta: 0.43867060648746675
# ------Epoch 79746------
# Best fit theta: [-3.87509451  0.02941567  0.03929343]
# Cost function at best fit theta: 0.4386693066036811
# ------Epoch 79747------
# Best fit theta: [-3.87513057  0.02941595  0.0392937 ]
# Cost function at best fit theta: 0.4386680067362155
# ------Epoch 79748------
# Best fit theta: [-3.87516663  0.02941624  0.03929397]
# Cost function at best fit theta: 0.4386667068850701
# ------Epoch 79749------
# Best fit theta: [-3.8752027   0.02941652  0.03929423]
# Cost function at best fit theta: 0.43866540705024415
# ------Epoch 79750------
# Best fit theta: [-3.87523876  0.0294168   0.0392945 ]
# Cost function at best fit theta: 0.43866410723173765
# ------Epoch 79751------
# Best fit theta: [-3.87527482  0.02941708  0.03929477]
# Cost function at best fit theta: 0.4386628074295503
# ------Epoch 79752------
# Best fit theta: [-3.87531088  0.02941736  0.03929504]
# Cost function at best fit theta: 0.4386615076436818
# ------Epoch 79753------
# Best fit theta: [-3.87534694  0.02941765  0.03929531]
# Cost function at best fit theta: 0.43866020787413174
# ------Epoch 79754------
# Best fit theta: [-3.87538301  0.02941793  0.03929558]
# Cost function at best fit theta: 0.43865890812089997
# ------Epoch 79755------
# Best fit theta: [-3.87541907  0.02941821  0.03929584]
# Cost function at best fit theta: 0.4386576083839862
# ------Epoch 79756------
# Best fit theta: [-3.87545513  0.02941849  0.03929611]
# Cost function at best fit theta: 0.43865630866339
# ------Epoch 79757------
# Best fit theta: [-3.87549119  0.02941877  0.03929638]
# Cost function at best fit theta: 0.4386550089591113
# ------Epoch 79758------
# Best fit theta: [-3.87552725  0.02941906  0.03929665]
# Cost function at best fit theta: 0.4386537092711497
# ------Epoch 79759------
# Best fit theta: [-3.87556331  0.02941934  0.03929692]
# Cost function at best fit theta: 0.43865240959950486
# ------Epoch 79760------
# Best fit theta: [-3.87559937  0.02941962  0.03929718]
# Cost function at best fit theta: 0.4386511099441766
# ------Epoch 79761------
# Best fit theta: [-3.87563543  0.0294199   0.03929745]
# Cost function at best fit theta: 0.4386498103051646
# ------Epoch 79762------
# Best fit theta: [-3.87567149  0.02942019  0.03929772]
# Cost function at best fit theta: 0.43864851068246846
# ------Epoch 79763------
# Best fit theta: [-3.87570755  0.02942047  0.03929799]
# Cost function at best fit theta: 0.4386472110760881
# ------Epoch 79764------
# Best fit theta: [-3.87574361  0.02942075  0.03929826]
# Cost function at best fit theta: 0.43864591148602317
# ------Epoch 79765------
# Best fit theta: [-3.87577967  0.02942103  0.03929853]
# Cost function at best fit theta: 0.4386446119122732
# ------Epoch 79766------
# Best fit theta: [-3.87581573  0.02942131  0.03929879]
# Cost function at best fit theta: 0.43864331235483806
# ------Epoch 79767------
# Best fit theta: [-3.87585179  0.0294216   0.03929906]
# Cost function at best fit theta: 0.4386420128137176
# ------Epoch 79768------
# Best fit theta: [-3.87588784  0.02942188  0.03929933]
# Cost function at best fit theta: 0.43864071328891124
# ------Epoch 79769------
# Best fit theta: [-3.8759239   0.02942216  0.0392996 ]
# Cost function at best fit theta: 0.4386394137804189
# ------Epoch 79770------
# Best fit theta: [-3.87595996  0.02942244  0.03929987]
# Cost function at best fit theta: 0.4386381142882402
# ------Epoch 79771------
# Best fit theta: [-3.87599602  0.02942272  0.03930014]
# Cost function at best fit theta: 0.43863681481237493
# ------Epoch 79772------
# Best fit theta: [-3.87603208  0.02942301  0.0393004 ]
# Cost function at best fit theta: 0.4386355153528228
# ------Epoch 79773------
# Best fit theta: [-3.87606813  0.02942329  0.03930067]
# Cost function at best fit theta: 0.43863421590958346
# ------Epoch 79774------
# Best fit theta: [-3.87610419  0.02942357  0.03930094]
# Cost function at best fit theta: 0.4386329164826566
# ------Epoch 79775------
# Best fit theta: [-3.87614025  0.02942385  0.03930121]
# Cost function at best fit theta: 0.43863161707204207
# ------Epoch 79776------
# Best fit theta: [-3.8761763   0.02942413  0.03930148]
# Cost function at best fit theta: 0.43863031767773947
# ------Epoch 79777------
# Best fit theta: [-3.87621236  0.02942442  0.03930174]
# Cost function at best fit theta: 0.43862901829974843
# ------Epoch 79778------
# Best fit theta: [-3.87624842  0.0294247   0.03930201]
# Cost function at best fit theta: 0.43862771893806896
# ------Epoch 79779------
# Best fit theta: [-3.87628447  0.02942498  0.03930228]
# Cost function at best fit theta: 0.43862641959270054
# ------Epoch 79780------
# Best fit theta: [-3.87632053  0.02942526  0.03930255]
# Cost function at best fit theta: 0.4386251202636429
# ------Epoch 79781------
# Best fit theta: [-3.87635658  0.02942555  0.03930282]
# Cost function at best fit theta: 0.4386238209508958
# ------Epoch 79782------
# Best fit theta: [-3.87639264  0.02942583  0.03930309]
# Cost function at best fit theta: 0.438622521654459
# ------Epoch 79783------
# Best fit theta: [-3.87642869  0.02942611  0.03930335]
# Cost function at best fit theta: 0.4386212223743321
# ------Epoch 79784------
# Best fit theta: [-3.87646475  0.02942639  0.03930362]
# Cost function at best fit theta: 0.43861992311051495
# ------Epoch 79785------
# Best fit theta: [-3.8765008   0.02942667  0.03930389]
# Cost function at best fit theta: 0.4386186238630072
# ------Epoch 79786------
# Best fit theta: [-3.87653686  0.02942696  0.03930416]
# Cost function at best fit theta: 0.43861732463180847
# ------Epoch 79787------
# Best fit theta: [-3.87657291  0.02942724  0.03930443]
# Cost function at best fit theta: 0.4386160254169186
# ------Epoch 79788------
# Best fit theta: [-3.87660897  0.02942752  0.03930469]
# Cost function at best fit theta: 0.43861472621833725
# ------Epoch 79789------
# Best fit theta: [-3.87664502  0.0294278   0.03930496]
# Cost function at best fit theta: 0.43861342703606415
# ------Epoch 79790------
# Best fit theta: [-3.87668107  0.02942808  0.03930523]
# Cost function at best fit theta: 0.43861212787009907
# ------Epoch 79791------
# Best fit theta: [-3.87671713  0.02942837  0.0393055 ]
# Cost function at best fit theta: 0.4386108287204416
# ------Epoch 79792------
# Best fit theta: [-3.87675318  0.02942865  0.03930577]
# Cost function at best fit theta: 0.4386095295870915
# ------Epoch 79793------
# Best fit theta: [-3.87678923  0.02942893  0.03930604]
# Cost function at best fit theta: 0.4386082304700486
# ------Epoch 79794------
# Best fit theta: [-3.87682529  0.02942921  0.0393063 ]
# Cost function at best fit theta: 0.4386069313693125
# ------Epoch 79795------
# Best fit theta: [-3.87686134  0.02942949  0.03930657]
# Cost function at best fit theta: 0.4386056322848829
# ------Epoch 79796------
# Best fit theta: [-3.87689739  0.02942978  0.03930684]
# Cost function at best fit theta: 0.43860433321675957
# ------Epoch 79797------
# Best fit theta: [-3.87693344  0.02943006  0.03930711]
# Cost function at best fit theta: 0.4386030341649423
# ------Epoch 79798------
# Best fit theta: [-3.87696949  0.02943034  0.03930738]
# Cost function at best fit theta: 0.4386017351294306
# ------Epoch 79799------
# Best fit theta: [-3.87700554  0.02943062  0.03930764]
# Cost function at best fit theta: 0.43860043611022426
# ------Epoch 79800------
# Best fit theta: [-3.8770416   0.0294309   0.03930791]
# Cost function at best fit theta: 0.4385991371073231
# ------Epoch 79801------
# Best fit theta: [-3.87707765  0.02943119  0.03930818]
# Cost function at best fit theta: 0.4385978381207268
# ------Epoch 79802------
# Best fit theta: [-3.8771137   0.02943147  0.03930845]
# Cost function at best fit theta: 0.43859653915043495
# ------Epoch 79803------
# Best fit theta: [-3.87714975  0.02943175  0.03930872]
# Cost function at best fit theta: 0.43859524019644736
# ------Epoch 79804------
# Best fit theta: [-3.8771858   0.02943203  0.03930899]
# Cost function at best fit theta: 0.4385939412587638
# ------Epoch 79805------
# Best fit theta: [-3.87722185  0.02943232  0.03930925]
# Cost function at best fit theta: 0.43859264233738393
# ------Epoch 79806------
# Best fit theta: [-3.8772579   0.0294326   0.03930952]
# Cost function at best fit theta: 0.4385913434323074
# ------Epoch 79807------
# Best fit theta: [-3.87729395  0.02943288  0.03930979]
# Cost function at best fit theta: 0.4385900445435339
# ------Epoch 79808------
# Best fit theta: [-3.87733     0.02943316  0.03931006]
# Cost function at best fit theta: 0.43858874567106343
# ------Epoch 79809------
# Best fit theta: [-3.87736605  0.02943344  0.03931033]
# Cost function at best fit theta: 0.4385874468148955
# ------Epoch 79810------
# Best fit theta: [-3.8774021   0.02943373  0.03931059]
# Cost function at best fit theta: 0.43858614797502976
# ------Epoch 79811------
# Best fit theta: [-3.87743814  0.02943401  0.03931086]
# Cost function at best fit theta: 0.4385848491514657
# ------Epoch 79812------
# Best fit theta: [-3.87747419  0.02943429  0.03931113]
# Cost function at best fit theta: 0.43858355034420377
# ------Epoch 79813------
# Best fit theta: [-3.87751024  0.02943457  0.0393114 ]
# Cost function at best fit theta: 0.43858225155324293
# ------Epoch 79814------
# Best fit theta: [-3.87754629  0.02943485  0.03931167]
# Cost function at best fit theta: 0.43858095277858344
# ------Epoch 79815------
# Best fit theta: [-3.87758234  0.02943514  0.03931194]
# Cost function at best fit theta: 0.4385796540202247
# ------Epoch 79816------
# Best fit theta: [-3.87761838  0.02943542  0.0393122 ]
# Cost function at best fit theta: 0.4385783552781664
# ------Epoch 79817------
# Best fit theta: [-3.87765443  0.0294357   0.03931247]
# Cost function at best fit theta: 0.4385770565524084
# ------Epoch 79818------
# Best fit theta: [-3.87769048  0.02943598  0.03931274]
# Cost function at best fit theta: 0.4385757578429505
# ------Epoch 79819------
# Best fit theta: [-3.87772653  0.02943626  0.03931301]
# Cost function at best fit theta: 0.43857445914979215
# ------Epoch 79820------
# Best fit theta: [-3.87776257  0.02943655  0.03931328]
# Cost function at best fit theta: 0.4385731604729333
# ------Epoch 79821------
# Best fit theta: [-3.87779862  0.02943683  0.03931354]
# Cost function at best fit theta: 0.4385718618123735
# ------Epoch 79822------
# Best fit theta: [-3.87783467  0.02943711  0.03931381]
# Cost function at best fit theta: 0.4385705631681125
# ------Epoch 79823------
# Best fit theta: [-3.87787071  0.02943739  0.03931408]
# Cost function at best fit theta: 0.43856926454015016
# ------Epoch 79824------
# Best fit theta: [-3.87790676  0.02943767  0.03931435]
# Cost function at best fit theta: 0.43856796592848596
# ------Epoch 79825------
# Best fit theta: [-3.8779428   0.02943796  0.03931462]
# Cost function at best fit theta: 0.4385666673331198
# ------Epoch 79826------
# Best fit theta: [-3.87797885  0.02943824  0.03931488]
# Cost function at best fit theta: 0.4385653687540514
# ------Epoch 79827------
# Best fit theta: [-3.87801489  0.02943852  0.03931515]
# Cost function at best fit theta: 0.43856407019128024
# ------Epoch 79828------
# Best fit theta: [-3.87805094  0.0294388   0.03931542]
# Cost function at best fit theta: 0.4385627716448063
# ------Epoch 79829------
# Best fit theta: [-3.87808698  0.02943908  0.03931569]
# Cost function at best fit theta: 0.43856147311462923
# ------Epoch 79830------
# Best fit theta: [-3.87812303  0.02943937  0.03931596]
# Cost function at best fit theta: 0.43856017460074864
# ------Epoch 79831------
# Best fit theta: [-3.87815907  0.02943965  0.03931623]
# Cost function at best fit theta: 0.43855887610316424
# ------Epoch 79832------
# Best fit theta: [-3.87819512  0.02943993  0.03931649]
# Cost function at best fit theta: 0.43855757762187597
# ------Epoch 79833------
# Best fit theta: [-3.87823116  0.02944021  0.03931676]
# Cost function at best fit theta: 0.4385562791568832
# ------Epoch 79834------
# Best fit theta: [-3.8782672   0.02944049  0.03931703]
# Cost function at best fit theta: 0.43855498070818616
# ------Epoch 79835------
# Best fit theta: [-3.87830325  0.02944078  0.0393173 ]
# Cost function at best fit theta: 0.43855368227578395
# ------Epoch 79836------
# Best fit theta: [-3.87833929  0.02944106  0.03931757]
# Cost function at best fit theta: 0.4385523838596767
# ------Epoch 79837------
# Best fit theta: [-3.87837533  0.02944134  0.03931783]
# Cost function at best fit theta: 0.43855108545986404
# ------Epoch 79838------
# Best fit theta: [-3.87841137  0.02944162  0.0393181 ]
# Cost function at best fit theta: 0.43854978707634557
# ------Epoch 79839------
# Best fit theta: [-3.87844742  0.0294419   0.03931837]
# Cost function at best fit theta: 0.43854848870912116
# ------Epoch 79840------
# Best fit theta: [-3.87848346  0.02944219  0.03931864]
# Cost function at best fit theta: 0.43854719035819023
# ------Epoch 79841------
# Best fit theta: [-3.8785195   0.02944247  0.03931891]
# Cost function at best fit theta: 0.43854589202355293
# ------Epoch 79842------
# Best fit theta: [-3.87855554  0.02944275  0.03931917]
# Cost function at best fit theta: 0.4385445937052088
# ------Epoch 79843------
# Best fit theta: [-3.87859158  0.02944303  0.03931944]
# Cost function at best fit theta: 0.4385432954031574
# ------Epoch 79844------
# Best fit theta: [-3.87862763  0.02944331  0.03931971]
# Cost function at best fit theta: 0.4385419971173986
# ------Epoch 79845------
# Best fit theta: [-3.87866367  0.0294436   0.03931998]
# Cost function at best fit theta: 0.43854069884793206
# ------Epoch 79846------
# Best fit theta: [-3.87869971  0.02944388  0.03932025]
# Cost function at best fit theta: 0.43853940059475743
# ------Epoch 79847------
# Best fit theta: [-3.87873575  0.02944416  0.03932052]
# Cost function at best fit theta: 0.4385381023578746
# ------Epoch 79848------
# Best fit theta: [-3.87877179  0.02944444  0.03932078]
# Cost function at best fit theta: 0.4385368041372832
# ------Epoch 79849------
# Best fit theta: [-3.87880783  0.02944472  0.03932105]
# Cost function at best fit theta: 0.4385355059329829
# ------Epoch 79850------
# Best fit theta: [-3.87884387  0.02944501  0.03932132]
# Cost function at best fit theta: 0.4385342077449734
# ------Epoch 79851------
# Best fit theta: [-3.87887991  0.02944529  0.03932159]
# Cost function at best fit theta: 0.43853290957325447
# ------Epoch 79852------
# Best fit theta: [-3.87891595  0.02944557  0.03932186]
# Cost function at best fit theta: 0.4385316114178258
# ------Epoch 79853------
# Best fit theta: [-3.87895199  0.02944585  0.03932212]
# Cost function at best fit theta: 0.43853031327868713
# ------Epoch 79854------
# Best fit theta: [-3.87898803  0.02944613  0.03932239]
# Cost function at best fit theta: 0.43852901515583825
# ------Epoch 79855------
# Best fit theta: [-3.87902406  0.02944642  0.03932266]
# Cost function at best fit theta: 0.4385277170492787
# ------Epoch 79856------
# Best fit theta: [-3.8790601   0.0294467   0.03932293]
# Cost function at best fit theta: 0.43852641895900835
# ------Epoch 79857------
# Best fit theta: [-3.87909614  0.02944698  0.0393232 ]
# Cost function at best fit theta: 0.43852512088502676
# ------Epoch 79858------
# Best fit theta: [-3.87913218  0.02944726  0.03932346]
# Cost function at best fit theta: 0.43852382282733376
# ------Epoch 79859------
# Best fit theta: [-3.87916822  0.02944754  0.03932373]
# Cost function at best fit theta: 0.4385225247859292
# ------Epoch 79860------
# Best fit theta: [-3.87920426  0.02944783  0.039324  ]
# Cost function at best fit theta: 0.4385212267608124
# ------Epoch 79861------
# Best fit theta: [-3.87924029  0.02944811  0.03932427]
# Cost function at best fit theta: 0.4385199287519834
# ------Epoch 79862------
# Best fit theta: [-3.87927633  0.02944839  0.03932454]
# Cost function at best fit theta: 0.4385186307594419
# ------Epoch 79863------
# Best fit theta: [-3.87931237  0.02944867  0.0393248 ]
# Cost function at best fit theta: 0.43851733278318755
# ------Epoch 79864------
# Best fit theta: [-3.8793484   0.02944895  0.03932507]
# Cost function at best fit theta: 0.43851603482321994
# ------Epoch 79865------
# Best fit theta: [-3.87938444  0.02944924  0.03932534]
# Cost function at best fit theta: 0.4385147368795389
# ------Epoch 79866------
# Best fit theta: [-3.87942048  0.02944952  0.03932561]
# Cost function at best fit theta: 0.43851343895214423
# ------Epoch 79867------
# Best fit theta: [-3.87945651  0.0294498   0.03932588]
# Cost function at best fit theta: 0.4385121410410354
# ------Epoch 79868------
# Best fit theta: [-3.87949255  0.02945008  0.03932614]
# Cost function at best fit theta: 0.4385108431462124
# ------Epoch 79869------
# Best fit theta: [-3.87952858  0.02945036  0.03932641]
# Cost function at best fit theta: 0.43850954526767494
# ------Epoch 79870------
# Best fit theta: [-3.87956462  0.02945064  0.03932668]
# Cost function at best fit theta: 0.43850824740542244
# ------Epoch 79871------
# Best fit theta: [-3.87960065  0.02945093  0.03932695]
# Cost function at best fit theta: 0.43850694955945485
# ------Epoch 79872------
# Best fit theta: [-3.87963669  0.02945121  0.03932722]
# Cost function at best fit theta: 0.4385056517297719
# ------Epoch 79873------
# Best fit theta: [-3.87967272  0.02945149  0.03932749]
# Cost function at best fit theta: 0.4385043539163732
# ------Epoch 79874------
# Best fit theta: [-3.87970876  0.02945177  0.03932775]
# Cost function at best fit theta: 0.43850305611925844
# ------Epoch 79875------
# Best fit theta: [-3.87974479  0.02945205  0.03932802]
# Cost function at best fit theta: 0.43850175833842747
# ------Epoch 79876------
# Best fit theta: [-3.87978083  0.02945234  0.03932829]
# Cost function at best fit theta: 0.43850046057388
# ------Epoch 79877------
# Best fit theta: [-3.87981686  0.02945262  0.03932856]
# Cost function at best fit theta: 0.4384991628256156
# ------Epoch 79878------
# Best fit theta: [-3.87985289  0.0294529   0.03932883]
# Cost function at best fit theta: 0.4384978650936341
# ------Epoch 79879------
# Best fit theta: [-3.87988893  0.02945318  0.03932909]
# Cost function at best fit theta: 0.43849656737793513
# ------Epoch 79880------
# Best fit theta: [-3.87992496  0.02945346  0.03932936]
# Cost function at best fit theta: 0.43849526967851843
# ------Epoch 79881------
# Best fit theta: [-3.87996099  0.02945375  0.03932963]
# Cost function at best fit theta: 0.4384939719953838
# ------Epoch 79882------
# Best fit theta: [-3.87999703  0.02945403  0.0393299 ]
# Cost function at best fit theta: 0.4384926743285309
# ------Epoch 79883------
# Best fit theta: [-3.88003306  0.02945431  0.03933017]
# Cost function at best fit theta: 0.43849137667795934
# ------Epoch 79884------
# Best fit theta: [-3.88006909  0.02945459  0.03933043]
# Cost function at best fit theta: 0.43849007904366893
# ------Epoch 79885------
# Best fit theta: [-3.88010512  0.02945487  0.0393307 ]
# Cost function at best fit theta: 0.4384887814256595
# ------Epoch 79886------
# Best fit theta: [-3.88014116  0.02945516  0.03933097]
# Cost function at best fit theta: 0.43848748382393066
# ------Epoch 79887------
# Best fit theta: [-3.88017719  0.02945544  0.03933124]
# Cost function at best fit theta: 0.438486186238482
# ------Epoch 79888------
# Best fit theta: [-3.88021322  0.02945572  0.03933151]
# Cost function at best fit theta: 0.43848488866931357
# ------Epoch 79889------
# Best fit theta: [-3.88024925  0.029456    0.03933177]
# Cost function at best fit theta: 0.43848359111642465
# ------Epoch 79890------
# Best fit theta: [-3.88028528  0.02945628  0.03933204]
# Cost function at best fit theta: 0.4384822935798152
# ------Epoch 79891------
# Best fit theta: [-3.88032131  0.02945657  0.03933231]
# Cost function at best fit theta: 0.438480996059485
# ------Epoch 79892------
# Best fit theta: [-3.88035734  0.02945685  0.03933258]
# Cost function at best fit theta: 0.4384796985554337
# ------Epoch 79893------
# Best fit theta: [-3.88039337  0.02945713  0.03933285]
# Cost function at best fit theta: 0.43847840106766095
# ------Epoch 79894------
# Best fit theta: [-3.8804294   0.02945741  0.03933311]
# Cost function at best fit theta: 0.43847710359616643
# ------Epoch 79895------
# Best fit theta: [-3.88046543  0.02945769  0.03933338]
# Cost function at best fit theta: 0.43847580614095005
# ------Epoch 79896------
# Best fit theta: [-3.88050146  0.02945797  0.03933365]
# Cost function at best fit theta: 0.4384745087020113
# ------Epoch 79897------
# Best fit theta: [-3.88053749  0.02945826  0.03933392]
# Cost function at best fit theta: 0.43847321127934996
# ------Epoch 79898------
# Best fit theta: [-3.88057352  0.02945854  0.03933419]
# Cost function at best fit theta: 0.4384719138729659
# ------Epoch 79899------
# Best fit theta: [-3.88060955  0.02945882  0.03933445]
# Cost function at best fit theta: 0.4384706164828588
# ------Epoch 79900------
# Best fit theta: [-3.88064558  0.0294591   0.03933472]
# Cost function at best fit theta: 0.4384693191090281
# ------Epoch 79901------
# Best fit theta: [-3.8806816   0.02945938  0.03933499]
# Cost function at best fit theta: 0.4384680217514738
# ------Epoch 79902------
# Best fit theta: [-3.88071763  0.02945967  0.03933526]
# Cost function at best fit theta: 0.43846672441019546
# ------Epoch 79903------
# Best fit theta: [-3.88075366  0.02945995  0.03933553]
# Cost function at best fit theta: 0.43846542708519304
# ------Epoch 79904------
# Best fit theta: [-3.88078969  0.02946023  0.03933579]
# Cost function at best fit theta: 0.43846412977646587
# ------Epoch 79905------
# Best fit theta: [-3.88082572  0.02946051  0.03933606]
# Cost function at best fit theta: 0.4384628324840141
# ------Epoch 79906------
# Best fit theta: [-3.88086174  0.02946079  0.03933633]
# Cost function at best fit theta: 0.43846153520783704
# ------Epoch 79907------
# Best fit theta: [-3.88089777  0.02946108  0.0393366 ]
# Cost function at best fit theta: 0.43846023794793454
# ------Epoch 79908------
# Best fit theta: [-3.8809338   0.02946136  0.03933687]
# Cost function at best fit theta: 0.4384589407043065
# ------Epoch 79909------
# Best fit theta: [-3.88096982  0.02946164  0.03933713]
# Cost function at best fit theta: 0.4384576434769524
# ------Epoch 79910------
# Best fit theta: [-3.88100585  0.02946192  0.0393374 ]
# Cost function at best fit theta: 0.4384563462658721
# ------Epoch 79911------
# Best fit theta: [-3.88104188  0.0294622   0.03933767]
# Cost function at best fit theta: 0.4384550490710652
# ------Epoch 79912------
# Best fit theta: [-3.8810779   0.02946249  0.03933794]
# Cost function at best fit theta: 0.4384537518925316
# ------Epoch 79913------
# Best fit theta: [-3.88111393  0.02946277  0.03933821]
# Cost function at best fit theta: 0.4384524547302707
# ------Epoch 79914------
# Best fit theta: [-3.88114995  0.02946305  0.03933847]
# Cost function at best fit theta: 0.4384511575842827
# ------Epoch 79915------
# Best fit theta: [-3.88118598  0.02946333  0.03933874]
# Cost function at best fit theta: 0.4384498604545668
# ------Epoch 79916------
# Best fit theta: [-3.881222    0.02946361  0.03933901]
# Cost function at best fit theta: 0.438448563341123
# ------Epoch 79917------
# Best fit theta: [-3.88125803  0.02946389  0.03933928]
# Cost function at best fit theta: 0.43844726624395086
# ------Epoch 79918------
# Best fit theta: [-3.88129405  0.02946418  0.03933955]
# Cost function at best fit theta: 0.4384459691630504
# ------Epoch 79919------
# Best fit theta: [-3.88133008  0.02946446  0.03933981]
# Cost function at best fit theta: 0.4384446720984209
# ------Epoch 79920------
# Best fit theta: [-3.8813661   0.02946474  0.03934008]
# Cost function at best fit theta: 0.4384433750500624
# ------Epoch 79921------
# Best fit theta: [-3.88140213  0.02946502  0.03934035]
# Cost function at best fit theta: 0.4384420780179746
# ------Epoch 79922------
# Best fit theta: [-3.88143815  0.0294653   0.03934062]
# Cost function at best fit theta: 0.4384407810021569
# ------Epoch 79923------
# Best fit theta: [-3.88147417  0.02946559  0.03934089]
# Cost function at best fit theta: 0.43843948400260946
# ------Epoch 79924------
# Best fit theta: [-3.8815102   0.02946587  0.03934115]
# Cost function at best fit theta: 0.4384381870193318
# ------Epoch 79925------
# Best fit theta: [-3.88154622  0.02946615  0.03934142]
# Cost function at best fit theta: 0.43843689005232345
# ------Epoch 79926------
# Best fit theta: [-3.88158224  0.02946643  0.03934169]
# Cost function at best fit theta: 0.43843559310158436
# ------Epoch 79927------
# Best fit theta: [-3.88161826  0.02946671  0.03934196]
# Cost function at best fit theta: 0.43843429616711416
# ------Epoch 79928------
# Best fit theta: [-3.88165429  0.02946699  0.03934223]
# Cost function at best fit theta: 0.4384329992489127
# ------Epoch 79929------
# Best fit theta: [-3.88169031  0.02946728  0.03934249]
# Cost function at best fit theta: 0.4384317023469795
# ------Epoch 79930------
# Best fit theta: [-3.88172633  0.02946756  0.03934276]
# Cost function at best fit theta: 0.4384304054613143
# ------Epoch 79931------
# Best fit theta: [-3.88176235  0.02946784  0.03934303]
# Cost function at best fit theta: 0.4384291085919169
# ------Epoch 79932------
# Best fit theta: [-3.88179837  0.02946812  0.0393433 ]
# Cost function at best fit theta: 0.438427811738787
# ------Epoch 79933------
# Best fit theta: [-3.88183439  0.0294684   0.03934357]
# Cost function at best fit theta: 0.4384265149019244
# ------Epoch 79934------
# Best fit theta: [-3.88187042  0.02946869  0.03934383]
# Cost function at best fit theta: 0.43842521808132856
# ------Epoch 79935------
# Best fit theta: [-3.88190644  0.02946897  0.0393441 ]
# Cost function at best fit theta: 0.4384239212769994
# ------Epoch 79936------
# Best fit theta: [-3.88194246  0.02946925  0.03934437]
# Cost function at best fit theta: 0.43842262448893654
# ------Epoch 79937------
# Best fit theta: [-3.88197848  0.02946953  0.03934464]
# Cost function at best fit theta: 0.4384213277171398
# ------Epoch 79938------
# Best fit theta: [-3.8820145   0.02946981  0.03934491]
# Cost function at best fit theta: 0.4384200309616089
# ------Epoch 79939------
# Best fit theta: [-3.88205052  0.02947009  0.03934517]
# Cost function at best fit theta: 0.43841873422234345
# ------Epoch 79940------
# Best fit theta: [-3.88208654  0.02947038  0.03934544]
# Cost function at best fit theta: 0.4384174374993431
# ------Epoch 79941------
# Best fit theta: [-3.88212256  0.02947066  0.03934571]
# Cost function at best fit theta: 0.43841614079260777
# ------Epoch 79942------
# Best fit theta: [-3.88215857  0.02947094  0.03934598]
# Cost function at best fit theta: 0.43841484410213705
# ------Epoch 79943------
# Best fit theta: [-3.88219459  0.02947122  0.03934624]
# Cost function at best fit theta: 0.4384135474279307
# ------Epoch 79944------
# Best fit theta: [-3.88223061  0.0294715   0.03934651]
# Cost function at best fit theta: 0.43841225076998847
# ------Epoch 79945------
# Best fit theta: [-3.88226663  0.02947179  0.03934678]
# Cost function at best fit theta: 0.4384109541283099
# ------Epoch 79946------
# Best fit theta: [-3.88230265  0.02947207  0.03934705]
# Cost function at best fit theta: 0.4384096575028949
# ------Epoch 79947------
# Best fit theta: [-3.88233867  0.02947235  0.03934732]
# Cost function at best fit theta: 0.4384083608937431
# ------Epoch 79948------
# Best fit theta: [-3.88237469  0.02947263  0.03934758]
# Cost function at best fit theta: 0.4384070643008542
# ------Epoch 79949------
# Best fit theta: [-3.8824107   0.02947291  0.03934785]
# Cost function at best fit theta: 0.438405767724228
# ------Epoch 79950------
# Best fit theta: [-3.88244672  0.02947319  0.03934812]
# Cost function at best fit theta: 0.4384044711638641
# ------Epoch 79951------
# Best fit theta: [-3.88248274  0.02947348  0.03934839]
# Cost function at best fit theta: 0.4384031746197624
# ------Epoch 79952------
# Best fit theta: [-3.88251875  0.02947376  0.03934866]
# Cost function at best fit theta: 0.4384018780919224
# ------Epoch 79953------
# Best fit theta: [-3.88255477  0.02947404  0.03934892]
# Cost function at best fit theta: 0.43840058158034384
# ------Epoch 79954------
# Best fit theta: [-3.88259079  0.02947432  0.03934919]
# Cost function at best fit theta: 0.43839928508502674
# ------Epoch 79955------
# Best fit theta: [-3.8826268   0.0294746   0.03934946]
# Cost function at best fit theta: 0.4383979886059704
# ------Epoch 79956------
# Best fit theta: [-3.88266282  0.02947489  0.03934973]
# Cost function at best fit theta: 0.43839669214317467
# ------Epoch 79957------
# Best fit theta: [-3.88269884  0.02947517  0.03935   ]
# Cost function at best fit theta: 0.4383953956966395
# ------Epoch 79958------
# Best fit theta: [-3.88273485  0.02947545  0.03935026]
# Cost function at best fit theta: 0.43839409926636425
# ------Epoch 79959------
# Best fit theta: [-3.88277087  0.02947573  0.03935053]
# Cost function at best fit theta: 0.4383928028523488
# ------Epoch 79960------
# Best fit theta: [-3.88280688  0.02947601  0.0393508 ]
# Cost function at best fit theta: 0.43839150645459296
# ------Epoch 79961------
# Best fit theta: [-3.8828429   0.02947629  0.03935107]
# Cost function at best fit theta: 0.43839021007309625
# ------Epoch 79962------
# Best fit theta: [-3.88287891  0.02947658  0.03935134]
# Cost function at best fit theta: 0.4383889137078586
# ------Epoch 79963------
# Best fit theta: [-3.88291493  0.02947686  0.0393516 ]
# Cost function at best fit theta: 0.4383876173588795
# ------Epoch 79964------
# Best fit theta: [-3.88295094  0.02947714  0.03935187]
# Cost function at best fit theta: 0.4383863210261588
# ------Epoch 79965------
# Best fit theta: [-3.88298695  0.02947742  0.03935214]
# Cost function at best fit theta: 0.4383850247096963
# ------Epoch 79966------
# Best fit theta: [-3.88302297  0.0294777   0.03935241]
# Cost function at best fit theta: 0.4383837284094915
# ------Epoch 79967------
# Best fit theta: [-3.88305898  0.02947799  0.03935268]
# Cost function at best fit theta: 0.43838243212554434
# ------Epoch 79968------
# Best fit theta: [-3.88309499  0.02947827  0.03935294]
# Cost function at best fit theta: 0.43838113585785426
# ------Epoch 79969------
# Best fit theta: [-3.88313101  0.02947855  0.03935321]
# Cost function at best fit theta: 0.4383798396064212
# ------Epoch 79970------
# Best fit theta: [-3.88316702  0.02947883  0.03935348]
# Cost function at best fit theta: 0.43837854337124477
# ------Epoch 79971------
# Best fit theta: [-3.88320303  0.02947911  0.03935375]
# Cost function at best fit theta: 0.43837724715232484
# ------Epoch 79972------
# Best fit theta: [-3.88323904  0.02947939  0.03935401]
# Cost function at best fit theta: 0.43837595094966103
# ------Epoch 79973------
# Best fit theta: [-3.88327506  0.02947968  0.03935428]
# Cost function at best fit theta: 0.43837465476325294
# ------Epoch 79974------
# Best fit theta: [-3.88331107  0.02947996  0.03935455]
# Cost function at best fit theta: 0.4383733585931004
# ------Epoch 79975------
# Best fit theta: [-3.88334708  0.02948024  0.03935482]
# Cost function at best fit theta: 0.4383720624392032
# ------Epoch 79976------
# Best fit theta: [-3.88338309  0.02948052  0.03935509]
# Cost function at best fit theta: 0.4383707663015608
# ------Epoch 79977------
# Best fit theta: [-3.8834191   0.0294808   0.03935535]
# Cost function at best fit theta: 0.43836947018017314
# ------Epoch 79978------
# Best fit theta: [-3.88345511  0.02948108  0.03935562]
# Cost function at best fit theta: 0.43836817407504
# ------Epoch 79979------
# Best fit theta: [-3.88349112  0.02948137  0.03935589]
# Cost function at best fit theta: 0.43836687798616086
# ------Epoch 79980------
# Best fit theta: [-3.88352714  0.02948165  0.03935616]
# Cost function at best fit theta: 0.43836558191353553
# ------Epoch 79981------
# Best fit theta: [-3.88356315  0.02948193  0.03935643]
# Cost function at best fit theta: 0.43836428585716386
# ------Epoch 79982------
# Best fit theta: [-3.88359916  0.02948221  0.03935669]
# Cost function at best fit theta: 0.43836298981704525
# ------Epoch 79983------
# Best fit theta: [-3.88363517  0.02948249  0.03935696]
# Cost function at best fit theta: 0.4383616937931798
# ------Epoch 79984------
# Best fit theta: [-3.88367118  0.02948278  0.03935723]
# Cost function at best fit theta: 0.43836039778556696
# ------Epoch 79985------
# Best fit theta: [-3.88370719  0.02948306  0.0393575 ]
# Cost function at best fit theta: 0.43835910179420656
# ------Epoch 79986------
# Best fit theta: [-3.88374319  0.02948334  0.03935776]
# Cost function at best fit theta: 0.4383578058190983
# ------Epoch 79987------
# Best fit theta: [-3.8837792   0.02948362  0.03935803]
# Cost function at best fit theta: 0.4383565098602417
# ------Epoch 79988------
# Best fit theta: [-3.88381521  0.0294839   0.0393583 ]
# Cost function at best fit theta: 0.4383552139176369
# ------Epoch 79989------
# Best fit theta: [-3.88385122  0.02948418  0.03935857]
# Cost function at best fit theta: 0.43835391799128326
# ------Epoch 79990------
# Best fit theta: [-3.88388723  0.02948447  0.03935884]
# Cost function at best fit theta: 0.43835262208118053
# ------Epoch 79991------
# Best fit theta: [-3.88392324  0.02948475  0.0393591 ]
# Cost function at best fit theta: 0.4383513261873286
# ------Epoch 79992------
# Best fit theta: [-3.88395924  0.02948503  0.03935937]
# Cost function at best fit theta: 0.4383500303097271
# ------Epoch 79993------
# Best fit theta: [-3.88399525  0.02948531  0.03935964]
# Cost function at best fit theta: 0.43834873444837563
# ------Epoch 79994------
# Best fit theta: [-3.88403126  0.02948559  0.03935991]
# Cost function at best fit theta: 0.43834743860327413
# ------Epoch 79995------
# Best fit theta: [-3.88406727  0.02948587  0.03936018]
# Cost function at best fit theta: 0.4383461427744221
# ------Epoch 79996------
# Best fit theta: [-3.88410327  0.02948616  0.03936044]
# Cost function at best fit theta: 0.4383448469618194
# ------Epoch 79997------
# Best fit theta: [-3.88413928  0.02948644  0.03936071]
# Cost function at best fit theta: 0.43834355116546564
# ------Epoch 79998------
# Best fit theta: [-3.88417529  0.02948672  0.03936098]
# Cost function at best fit theta: 0.4383422553853607
# ------Epoch 79999------
# Best fit theta: [-3.88421129  0.029487    0.03936125]
# Cost function at best fit theta: 0.43834095962150416

# %%
plotDecisionBoundary(theta, x, y)
print('Training Accuracy: {0}'.format(accuracy(x, y)))
# Out:
# Training Accuracy: 85.0
